# %% [markdown]
# # [ARCHIVE] FCC CMA Scraping - AMENDMENT

# %% [markdown]
# ## NOTE
#
# This is a re-run of scraping for CMA's with results equal to 10, due to ommission of pagination in first run
# * See scrape-callsigns_by_cma.ipynb for initial searchs
# * See REF_ULS-LicenseDatabase-scraping.ipynb for reference code

# %% [markdown]
# ## Set up selenium webdriver with Firefox
# * Download Firefox driver [geckodriver](https://github.com/mozilla/geckodriver/releases) for selenium
# * Move the driver executable into the same directory as this notebook (or update the path to the executable in `scrape_table_for_call_sign`)
# * `pip install selenium`
#
# -- see scrape-apps_by_callsign.ipynb for more details

# %%
from bs4 import BeautifulSoup
import time
import random
import csv

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options  
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException

# %%
import os
import pandas as pd

# %% [markdown]
# ## Define functions for scraping individual CMA

# %%
def extract_mkt_code(soup):
    '''
    Helper function that extracts the market code (CMA) from market search results page
    '''
    
    # tag attributes for element containing "Market Code = " 
    mkt_code_attrs = {"align" : "left", "class" : "cell-pri-light", "valign" : "bottom"}
    
    # extract mkt code as text
    mkt_code = (
        soup.find_all(attrs=mkt_code_attrs, limit=1)[0]
        .find_all("b")[0]
        .get_text()
    )
    
    return mkt_code

# %%
def extract_table_data(innerHTML):
    '''
    Extracts the following details by row from innerHTML of results page:
        * Market Code (CMA)
        * Call Sign/Lease ID
        * FRN Name
        * FRN Number
        * Radio Service
        * Status
        * Expiration Date
    Returns as list of rows (as list) without col_names
    '''
    
    
    # Extract search data from innerHTML soup
    soup = BeautifulSoup(innerHTML, "lxml")
    CMA = extract_mkt_code(soup)
    
    # extract search results as list of rows
    rows = (
        soup.find("table", {"summary": "License search results"})
        .find_all("tr")[1:-1] # exclude header/footer name rows
        )

    
    # extract results by row into table, attaching cma number
    table_data = [] 
    
    for row in rows:
        
        row_data = [CMA, ]          
        cols = row.find_all("td")
        
        # extract data from each cell in a row
        for i in range(1, len(cols)):  # skip first index num column
            cell_data = cols[i].get_text().strip()
            row_data.append(cell_data)
        
        table_data.append(row_data)
    
    return(table_data)

# %%
def cache_innerHTML(mkt_code, without_browser=False, cache_to='search-cache/html/'):
    '''
    Scrapes the FCC License Search database for a given Cellular Market Area (mkt_code)
    Caches innerHTML to 'search-cache/mkt_code.html'.
    Returns list of rows (as list) without col_names:
        * Market Code (CMA)
        * Call Sign/Lease ID
        * FRN Name
        * FRN Number
        * Radio Service
        * Status
        * Expiration Date
    '''

    tick = time.time()
    print("LOG[INFO]: START SCRAPE %s " % mkt_code)

          
    # driver config - start in private
    firefox_profile = webdriver.FirefoxProfile()
    firefox_profile.set_preference("browser.privatebrowsing.autostart", True)
    
    # (optional) don't open up browser
    firefox_options = Options()
    if without_browser:
        firefox_options.add_argument("--headless")

    # direct webdriver to search page
    search_url = "https://wireless2.fcc.gov/UlsApp/UlsSearch/searchMarket.jsp"
    
    firefox = webdriver.Firefox(options=firefox_options, executable_path="./geckodriver")
    firefox.get(search_url)

    # specify the market type we want to search for
    in_markettype = Select(firefox.find_element_by_id("marketType"))
    in_markettype.select_by_value("CMA")

    # specify the market we want to search for
    in_mkt = Select(firefox.find_element_by_id("ulsMarket"))
    in_mkt.deselect_by_visible_text("All")
    in_mkt.select_by_value(mkt_code)
    
    # set pagination to 100 (maximum)
    in_pagination = Select(firefox.find_element_by_name("fiRowsPerPage"))
    in_pagination.select_by_value("100")
        
    # submit search, wait for load
    firefox.find_element_by_name("marketSearch").submit()

    WebDriverWait(firefox, 15).until(EC.url_changes(search_url))
    WebDriverWait(firefox, 15).until(
        lambda _: firefox.execute_script("return document.readyState") == "complete"
        )
    
    # scrape innerHTML & cache
    innerHTML = firefox.execute_script("return document.body.innerHTML")
    
    with open("%s/%s.html" % (cache_to, mkt_code), 'w') as f:
        f.write(innerHTML)
    
    # quit webdriver
    firefox.quit()
        
    tock = time.time()
    print("LOG[INFO]: END SCRAPE %s (%2f seconds)" % (mkt_code, tock - tick))
    
    return innerHTML

# %%
def scrape_table_for_cma(mkt_code, without_browser=False, cache_to='search-cache'):
    '''
    Scrapes the FCC License Search database for a given Cellular Market Area (mkt_code)
    Caches innerHTML to 'search-cache/mkt_code.html'.
    Returns list of rows (as list) without col_names:
        * Market Code (CMA)
        * Call Sign/Lease ID
        * FRN Name
        * FRN Number
        * Radio Service
        * Status
        * Expiration Date
    '''
    
    # spin up webdriver & query database
    innerHTML = cache_innerHTML(mkt_code, without_browser, cache_to)
    
    # extract table data 
    table_data = []

    table_data += extract_table_data(innerHTML)
    
    return table_data

# %% [markdown]
# ## Define functions for searching for list of CMAs

# %%
def loop_scrape_table_for_cma(list_cma, max_tries=3, wait_query=True, wait_retry=True):
    '''
    Attempts to scrape for cma codes in `list_cma` up to `max_tries`. 
    Caches .html for each search.
    Returns all data in loop
    '''
    try:
        # start search & tries counter
        i = 0
        tries = 1

        # log start of loop
        tick = time.time()
        print(
            "LOG[INFO]: START TIME is %s\n"
            "LOG[INFO]: START LOOP from %s"
            % (time.strftime("%I:%M %p"), list_cma[i])
        )

        # begin search & scrape loop over mkt_codes
        loop_data = []

        # Attempt to scrape all cma's in list_cma up to 3 times
        while (i < len(list_cma) and tries <= max_tries):
            print("LOG[INFO]: Attempt", tries)
            # Succcessful iteration
            try:
                # search for i-th CMA
                mkt_code = list_cma[i]
                result = scrape_table_for_cma(mkt_code, True)

                loop_data += result
            
                # wait random time before next query
                i += 1
                waitTime_query = (
                    (random.randint(1,60)) 
                    if wait_query == True 
                    else 0
                )
                print("LOG[INFO]: WAIT %2f seconds before next query" % waitTime_query)
                time.sleep(waitTime_query)

            # Interrupted iteration logs time & error, and waits for retry
            except Exception as e:
                print(
                    "LOG[ERROR]: %s\n"
                    "LOG[INFO]: LOOP INTERRUPTED at %s\n"
                    % (e, time.strftime("%I:%M %p"))
                )
                # wait for next try
                tries += 1
                waitTime_retry = (
                    (random.randint(200,500)) 
                    if wait_retry == True 
                    else 0
                )
                if tries <= max_tries:
                    print("LOG[INFO]: WAIT %2f minutes to retry" % (waitTime_retry/60))
                    time.sleep(waitTime_retry)
                else:
                    pass

        # log end of while loop
        tock = time.time()
        print(
            "LOG[INFO]: END LOOP at %s with %s ATTEMPTS\n"
            "LOG[INFO]: END TIME is %s (TOTAL: %2f minutes)"
            % (list_cma[(i-1)], (tries), time.strftime("%I:%M %p"), ((tock - tick)/60))
        )
    
    finally:
        return (loop_data)

# %%
def cache_to_csv(lst, path):

    with open(path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerows(lst)

    with open(path, 'r', newline='') as f:
        reader = csv.reader(f)
        check = list(reader)

    assert(len(lst) == len(check))
    
    print('Wrote `lst` to path: %s' % path)

# %% [markdown]
# ## Scraping results tables for list of CMA's

# %% [markdown]
# ### Creating search lists

# %%
# load previous search results
cma_df = pd.read_csv("data-cache/cma_df.csv", dtype='object')

# select for CMA with count >= 10, and return as list
rows_per_cma = cma_df.groupby(['cma_no']).count()
IS_gt_10 = (rows_per_cma['callsign_leaseID'] == 10)
cma_gt_10 = rows_per_cma[IS_gt_10].reset_index()['cma_no']
cma_gt_10_search = cma_gt_10.tolist()
cma_gt_10_search
# Out:
# ['CMA002',
#  'CMA014',
#  'CMA015',
#  'CMA024',
#  'CMA026',
#  'CMA028',
#  'CMA029',
#  'CMA039',
#  'CMA041',
#  'CMA045',
#  'CMA053',
#  'CMA071',
#  'CMA074',
#  'CMA077',
#  'CMA081',
#  'CMA086',
#  'CMA089',
#  'CMA090',
#  'CMA097',
#  'CMA098',
#  'CMA101',
#  'CMA106',
#  'CMA113',
#  'CMA127',
#  'CMA128',
#  'CMA141',
#  'CMA152',
#  'CMA161',
#  'CMA162',
#  'CMA165',
#  'CMA166',
#  'CMA168',
#  'CMA171',
#  'CMA174',
#  'CMA176',
#  'CMA181',
#  'CMA185',
#  'CMA187',
#  'CMA188',
#  'CMA217',
#  'CMA221',
#  'CMA227',
#  'CMA234',
#  'CMA245',
#  'CMA246',
#  'CMA255',
#  'CMA264',
#  'CMA267',
#  'CMA268',
#  'CMA273',
#  'CMA274',
#  'CMA281',
#  'CMA283',
#  'CMA285',
#  'CMA286',
#  'CMA289',
#  'CMA290',
#  'CMA295',
#  'CMA297',
#  'CMA298',
#  'CMA299',
#  'CMA306',
#  'CMA307',
#  'CMA311',
#  'CMA313',
#  'CMA315',
#  'CMA316',
#  'CMA317',
#  'CMA318',
#  'CMA319',
#  'CMA320',
#  'CMA322',
#  'CMA323',
#  'CMA336',
#  'CMA337',
#  'CMA341',
#  'CMA342',
#  'CMA344',
#  'CMA348',
#  'CMA351',
#  'CMA352',
#  'CMA353',
#  'CMA354',
#  'CMA355',
#  'CMA356',
#  'CMA361',
#  'CMA362',
#  'CMA363',
#  'CMA367',
#  'CMA369',
#  'CMA374',
#  'CMA376',
#  'CMA378',
#  'CMA379',
#  'CMA380',
#  'CMA381',
#  'CMA383',
#  'CMA386',
#  'CMA388',
#  'CMA389',
#  'CMA390',
#  'CMA393',
#  'CMA394',
#  'CMA396',
#  'CMA397',
#  'CMA401',
#  'CMA402',
#  'CMA403',
#  'CMA407',
#  'CMA408',
#  'CMA412',
#  'CMA414',
#  'CMA417',
#  'CMA418',
#  'CMA419',
#  'CMA420',
#  'CMA421',
#  'CMA422',
#  'CMA423',
#  'CMA424',
#  'CMA425',
#  'CMA426',
#  'CMA427',
#  'CMA428',
#  'CMA429',
#  'CMA430',
#  'CMA431',
#  'CMA432',
#  'CMA433',
#  'CMA434',
#  'CMA440',
#  'CMA448',
#  'CMA450',
#  'CMA455',
#  'CMA456',
#  'CMA458',
#  'CMA459',
#  'CMA466',
#  'CMA483',
#  'CMA486',
#  'CMA487',
#  'CMA488',
#  'CMA489',
#  'CMA490',
#  'CMA491',
#  'CMA498',
#  'CMA503',
#  'CMA505',
#  'CMA523',
#  'CMA524',
#  'CMA525',
#  'CMA526',
#  'CMA528',
#  'CMA529',
#  'CMA530',
#  'CMA531',
#  'CMA532',
#  'CMA534',
#  'CMA538',
#  'CMA540',
#  'CMA541',
#  'CMA543',
#  'CMA544',
#  'CMA545',
#  'CMA546',
#  'CMA547',
#  'CMA548',
#  'CMA553',
#  'CMA554',
#  'CMA555',
#  'CMA557',
#  'CMA558',
#  'CMA566',
#  'CMA568',
#  'CMA569',
#  'CMA571',
#  'CMA572',
#  'CMA573',
#  'CMA575',
#  'CMA576',
#  'CMA577',
#  'CMA579',
#  'CMA580',
#  'CMA581',
#  'CMA582',
#  'CMA583',
#  'CMA584',
#  'CMA586',
#  'CMA589',
#  'CMA590',
#  'CMA598',
#  'CMA600',
#  'CMA607',
#  'CMA611',
#  'CMA625',
#  'CMA626',
#  'CMA631',
#  'CMA632',
#  'CMA634',
#  'CMA635',
#  'CMA636',
#  'CMA637',
#  'CMA638',
#  'CMA639',
#  'CMA640',
#  'CMA641',
#  'CMA642',
#  'CMA643',
#  'CMA653',
#  'CMA656',
#  'CMA658',
#  'CMA659',
#  'CMA660',
#  'CMA661',
#  'CMA663',
#  'CMA665',
#  'CMA666',
#  'CMA669',
#  'CMA670',
#  'CMA671',
#  'CMA673',
#  'CMA675',
#  'CMA676',
#  'CMA677',
#  'CMA678',
#  'CMA681',
#  'CMA709',
#  'CMA711',
#  'CMA712',
#  'CMA713',
#  'CMA714',
#  'CMA715',
#  'CMA716',
#  'CMA718',
#  'CMA719',
#  'CMA720',
#  'CMA721',
#  'CMA722']

# %%
len(cma_gt_10_search)
# Out:
# 238

# %% [markdown]
# ### Running searches
#
# ```python
# # search loop
# results = loop_scrape_table_for_cma(cma_gt_10_search[95:100])
#
# # cache results table as csv
# cache_to_csv(results,
#              path=('search-cache/csv/amend_%s_%s'
#                    % (results[0][0], results[-1][0]))
#              )
# ```
#
# 1. first search: CMA002-317
# 2. second search: CMA318-389;
#     * only cached html for CMA318-380
#     * messed up csv caching
# 3. third search: CMA390-722
#     * cached csv after using list.extend() to flatten list
# 4. fourth search: CMA381-389 (with HTML caching)
#     * supplementary search to extract data; correctly cached
# 5. fifth search: repeat CMA002-317
#     * cached to csv
#
# ### Caching to .csv
#
# 1. messed up first and second search -- each row was a list corresponding to a CMA; needed to flatten
#
# 2. re-cached data from html for CMA318-722
#
# ```python
# import os
#
# html_lst = sorted((os.listdir('search-cache/html'))) # lists html files for CMA318-722
#
# amend_2 = []
#
# for cma in html_lst:
#     with open('search-cache/html/%s' %cma, 'r') as f:
#         innerHTML = f
#         amend2.extend(extract_table_data(innerHTML))
# ```
#
# 3. unpack incorrectly cached first search (CMA002-317)
# ABORT -- too difficult; rerun first search above

# %%
! ls -1 'search-cache/html' | wc -l
# Out:
#      238

# %% [markdown]
# # amend 3 -- recache first search

# %%
results = loop_scrape_table_for_cma(cma_gt_10_search[:68])
# Out:
# LOG[INFO]: START TIME is 05:31 PM
# LOG[INFO]: START LOOP from CMA002
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA002
# LOG[INFO]: END SCRAPE CMA002 (15.675442 seconds)
# LOG[INFO]: WAIT 59.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA014
# LOG[INFO]: END SCRAPE CMA014 (22.533153 seconds)
# LOG[INFO]: WAIT 31.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA015
# LOG[INFO]: END SCRAPE CMA015 (27.720479 seconds)
# LOG[INFO]: WAIT 7.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA024
# LOG[INFO]: END SCRAPE CMA024 (17.576399 seconds)
# LOG[INFO]: WAIT 8.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA026
# LOG[INFO]: END SCRAPE CMA026 (17.784219 seconds)
# LOG[INFO]: WAIT 24.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA028
# LOG[INFO]: END SCRAPE CMA028 (20.945146 seconds)
# LOG[INFO]: WAIT 56.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA029
# LOG[INFO]: END SCRAPE CMA029 (23.242684 seconds)
# LOG[INFO]: WAIT 46.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA039
# LOG[INFO]: END SCRAPE CMA039 (23.806326 seconds)
# LOG[INFO]: WAIT 21.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA041
# LOG[INFO]: END SCRAPE CMA041 (20.327232 seconds)
# LOG[INFO]: WAIT 48.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA045
# LOG[INFO]: END SCRAPE CMA045 (23.115840 seconds)
# LOG[INFO]: WAIT 19.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA053
# LOG[INFO]: END SCRAPE CMA053 (19.190511 seconds)
# LOG[INFO]: WAIT 10.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA071
# LOG[INFO]: END SCRAPE CMA071 (20.221921 seconds)
# LOG[INFO]: WAIT 32.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA074
# LOG[INFO]: END SCRAPE CMA074 (19.780864 seconds)
# LOG[INFO]: WAIT 30.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA077
# LOG[INFO]: END SCRAPE CMA077 (22.240252 seconds)
# LOG[INFO]: WAIT 42.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA081
# LOG[INFO]: END SCRAPE CMA081 (19.969024 seconds)
# LOG[INFO]: WAIT 29.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA086
# LOG[INFO]: END SCRAPE CMA086 (20.777796 seconds)
# LOG[INFO]: WAIT 51.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA089
# LOG[INFO]: END SCRAPE CMA089 (22.135194 seconds)
# LOG[INFO]: WAIT 22.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA090
# LOG[INFO]: END SCRAPE CMA090 (23.235722 seconds)
# LOG[INFO]: WAIT 54.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA097
# LOG[INFO]: END SCRAPE CMA097 (19.583431 seconds)
# LOG[INFO]: WAIT 25.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA098
# LOG[INFO]: END SCRAPE CMA098 (18.401838 seconds)
# LOG[INFO]: WAIT 18.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA101
# LOG[INFO]: END SCRAPE CMA101 (21.952274 seconds)
# LOG[INFO]: WAIT 36.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA106
# LOG[INFO]: END SCRAPE CMA106 (16.411562 seconds)
# LOG[INFO]: WAIT 60.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA113
# LOG[INFO]: END SCRAPE CMA113 (16.542507 seconds)
# LOG[INFO]: WAIT 15.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA127
# LOG[INFO]: END SCRAPE CMA127 (17.214341 seconds)
# LOG[INFO]: WAIT 9.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA128
# LOG[INFO]: END SCRAPE CMA128 (15.940308 seconds)
# LOG[INFO]: WAIT 35.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA141
# LOG[INFO]: END SCRAPE CMA141 (14.761107 seconds)
# LOG[INFO]: WAIT 21.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA152
# LOG[INFO]: END SCRAPE CMA152 (14.211868 seconds)
# LOG[INFO]: WAIT 56.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA161
# LOG[INFO]: END SCRAPE CMA161 (18.552057 seconds)
# LOG[INFO]: WAIT 56.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA162
# LOG[INFO]: END SCRAPE CMA162 (16.691205 seconds)
# LOG[INFO]: WAIT 25.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA165
# LOG[INFO]: END SCRAPE CMA165 (20.269024 seconds)
# LOG[INFO]: WAIT 51.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA166
# LOG[INFO]: END SCRAPE CMA166 (19.004157 seconds)
# LOG[INFO]: WAIT 13.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA168
# LOG[INFO]: END SCRAPE CMA168 (23.119830 seconds)
# LOG[INFO]: WAIT 52.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA171
# LOG[INFO]: END SCRAPE CMA171 (17.909440 seconds)
# LOG[INFO]: WAIT 47.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA174
# LOG[INFO]: END SCRAPE CMA174 (19.014083 seconds)
# LOG[INFO]: WAIT 6.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA176
# LOG[INFO]: END SCRAPE CMA176 (25.302224 seconds)
# LOG[INFO]: WAIT 37.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA181
# LOG[INFO]: END SCRAPE CMA181 (19.717947 seconds)
# LOG[INFO]: WAIT 49.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA185
# LOG[INFO]: END SCRAPE CMA185 (16.834085 seconds)
# LOG[INFO]: WAIT 27.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA187
# LOG[INFO]: END SCRAPE CMA187 (16.414317 seconds)
# LOG[INFO]: WAIT 22.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA188
# LOG[INFO]: END SCRAPE CMA188 (15.213341 seconds)
# LOG[INFO]: WAIT 51.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA217
# LOG[INFO]: END SCRAPE CMA217 (23.202059 seconds)
# LOG[INFO]: WAIT 22.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA221
# LOG[INFO]: END SCRAPE CMA221 (26.927624 seconds)
# LOG[INFO]: WAIT 22.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA227
# LOG[INFO]: END SCRAPE CMA227 (22.346919 seconds)
# LOG[INFO]: WAIT 15.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA234
# LOG[INFO]: END SCRAPE CMA234 (16.334751 seconds)
# LOG[INFO]: WAIT 41.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA245
# LOG[INFO]: END SCRAPE CMA245 (21.244073 seconds)
# LOG[INFO]: WAIT 35.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA246
# LOG[INFO]: END SCRAPE CMA246 (14.023246 seconds)
# LOG[INFO]: WAIT 14.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA255
# LOG[INFO]: END SCRAPE CMA255 (19.230270 seconds)
# LOG[INFO]: WAIT 38.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA264
# LOG[INFO]: END SCRAPE CMA264 (16.802842 seconds)
# LOG[INFO]: WAIT 21.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA267
# LOG[INFO]: END SCRAPE CMA267 (18.456412 seconds)
# LOG[INFO]: WAIT 35.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA268
# LOG[INFO]: END SCRAPE CMA268 (17.456005 seconds)
# LOG[INFO]: WAIT 34.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA273
# LOG[INFO]: END SCRAPE CMA273 (23.256241 seconds)
# LOG[INFO]: WAIT 24.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA274
# LOG[INFO]: END SCRAPE CMA274 (19.757966 seconds)
# LOG[INFO]: WAIT 30.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA281
# LOG[INFO]: END SCRAPE CMA281 (21.959020 seconds)
# LOG[INFO]: WAIT 1.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA283
# LOG[INFO]: END SCRAPE CMA283 (23.612892 seconds)
# LOG[INFO]: WAIT 17.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA285
# LOG[INFO]: END SCRAPE CMA285 (29.368664 seconds)
# LOG[INFO]: WAIT 23.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA286
# LOG[INFO]: END SCRAPE CMA286 (22.028807 seconds)
# LOG[INFO]: WAIT 18.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA289
# LOG[INFO]: END SCRAPE CMA289 (26.486462 seconds)
# LOG[INFO]: WAIT 40.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA290
# LOG[INFO]: END SCRAPE CMA290 (17.674388 seconds)
# LOG[INFO]: WAIT 27.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA295
# LOG[INFO]: END SCRAPE CMA295 (25.419932 seconds)
# LOG[INFO]: WAIT 3.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA297
# LOG[INFO]: END SCRAPE CMA297 (24.557877 seconds)
# LOG[INFO]: WAIT 7.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA298
# LOG[INFO]: END SCRAPE CMA298 (24.247092 seconds)
# LOG[INFO]: WAIT 56.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA299
# LOG[INFO]: END SCRAPE CMA299 (21.099449 seconds)
# LOG[INFO]: WAIT 36.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA306
# LOG[INFO]: END SCRAPE CMA306 (24.672135 seconds)
# LOG[INFO]: WAIT 32.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA307
# LOG[INFO]: END SCRAPE CMA307 (22.011096 seconds)
# LOG[INFO]: WAIT 21.000000 seconds before next query
# LOG[INFO]: Attempt 1
# LOG[INFO]: START SCRAPE CMA311
# LOG[ERROR]: Message:
#
# LOG[INFO]: LOOP INTERRUPTED at 06:25 PM
#
# LOG[INFO]: WAIT 5.433333 minutes to retry
# LOG[INFO]: Attempt 2
# LOG[INFO]: START SCRAPE CMA311
# LOG[INFO]: END SCRAPE CMA311 (23.548290 seconds)
# LOG[INFO]: WAIT 6.000000 seconds before next query
# LOG[INFO]: Attempt 2
# LOG[INFO]: START SCRAPE CMA313
# LOG[INFO]: END SCRAPE CMA313 (23.827875 seconds)
# LOG[INFO]: WAIT 8.000000 seconds before next query
# LOG[INFO]: Attempt 2
# LOG[INFO]: START SCRAPE CMA315
# LOG[ERROR]: Message:
#
# LOG[INFO]: LOOP INTERRUPTED at 06:32 PM
#
# LOG[INFO]: WAIT 7.483333 minutes to retry
# LOG[INFO]: Attempt 3
# LOG[INFO]: START SCRAPE CMA315
# LOG[INFO]: END SCRAPE CMA315 (17.974172 seconds)
# LOG[INFO]: WAIT 2.000000 seconds before next query
# LOG[INFO]: Attempt 3
# LOG[INFO]: START SCRAPE CMA316
# LOG[INFO]: END SCRAPE CMA316 (26.466186 seconds)
# LOG[INFO]: WAIT 52.000000 seconds before next query
# LOG[INFO]: Attempt 3
# LOG[INFO]: START SCRAPE CMA317
# LOG[INFO]: END SCRAPE CMA317 (20.000534 seconds)
# LOG[INFO]: WAIT 11.000000 seconds before next query
# LOG[INFO]: END LOOP at CMA317 with 3 ATTEMPTS
# LOG[INFO]: END TIME is 06:41 PM (TOTAL: 70.386349 minutes)

# %%
path = ('search-cache/csv/amend_%s_%s.csv' % (results[0][0], results[-1][0]))
print(path)
# Out:
# search-cache/csv/amend_CMA002_CMA317.csv

# %%
cache_to_csv(results, path)
# Out:
# Wrote [['CMA002', 'KNKA209', 'Los Angeles SMSA Limited Partnership', '0002963817', 'CL', 'Active', '10/01/2024'], ['CMA002', 'KNKA351', 'AT&T Mobility Spectrum LLC', '0014980726', 'CL', 'Active', '10/01/2027'], ['CMA002', 'KNKR294', 'FOLDEN, GENE A', '', 'CL', 'Terminated', ''], ['CMA002', 'KNKR313', 'LOS ANGELES SMSA LIMITED PARTNERSHIP', '0002963817', 'CL', 'Canceled', '09/24/2007'], ['CMA002', 'L000009285', 'AirTouch Cellular', '0006146468', 'WY', 'Canceled', '06/13/2019'], ['CMA002', 'L000010911', 'Cellco Partnership', '0003290673', 'AW', 'Canceled', '01/25/2014'], ['CMA002', 'L000010913', 'New Cingular Wireless PCS, LLC', '0003291192', 'WY', 'Canceled', '01/25/2014'], ['CMA002', 'L000015067', 'Screened Images, Inc.', '0021044003', 'CL', 'Active', '10/01/2027'], ['CMA002', 'L000023743', 'Screened Images, Inc.', '0021044003', 'AW', 'Active', '11/29/2021'], ['CMA002', 'WPOI449', 'Los Angeles SMSA Limited Partnership-AirTouch Cellular', '0002963817', 'CL', 'Canceled', '02/18/2009'], ['CMA002', 'WPWU990', 'AT&T Mobility LLC', '0014980726', 'WZ', 'Active', '06/13/2019'], ['CMA002', 'WQGA742', 'AT&T Mobility Spectrum LLC', '0014980726', 'AW', 'Active', '11/29/2021'], ['CMA002', 'WQJQ721', 'AT&T Mobility Spectrum LLC', '0014980726', 'WY', 'Active', '06/13/2019'], ['CMA002', 'WQSH611', 'Cellco Partnership', '0003290673', 'AW', 'Active', '11/29/2021'], ['CMA002', 'WQWQ746', 'Northstar Wireless, LLC', '0023917453', 'AT', 'Active', '10/27/2027'], ['CMA014', 'KNKA232', 'Cellco Partnership', '0003290673', 'CL', 'Active', '10/01/2024'], ['CMA014', 'KNKA242', 'NEW CINGULAR WIRELESS PCS, LLC', '0003291192', 'CL', 'Active', '10/01/2023'], ['CMA014', 'L000010153', 'Tecore Government Services, LLC', '0019878172', 'AW', 'Active', '12/18/2021'], ['CMA014', 'L000011612', 'Tecore Government Services, LLC', '0019878172', 'CL', 'Expired', '10/01/2014'], ['CMA014', 'L000015304', 'Tecore Government Services, LLC', '0019878172', 'CL', 'Active', '10/01/2024'], ['CMA014', 'L000017021', 'Tecore Government Services, LLC', '0019878172', 'WZ', 'Active', '06/13/2019'], ['CMA014', 'L000017022', 'Tecore Government Services, LLC', '0019878172', 'WY', 'Active', '06/13/2019'], ['CMA014', 'L000017299', 'Tecore Government Services, LLC', '0019878172', 'CL', 'Active', '10/01/2023'], ['CMA014', 'WPWU996', 'New Cingular Wireless PCS, LLC', '0003291192', 'WZ', 'Active', '06/13/2019'], ['CMA014', 'WQGD674', 'New Cingular Wireless PCS, LLC', '0003291192', 'AW', 'Active', '12/18/2021'], ['CMA014', 'WQJU434', 'New Cingular Wireless PCS, LLC', '0003291192', 'WY', 'Active', '06/13/2019'], ['CMA014', 'WQWQ991', 'SNR Wireless LicenseCo, LLC', '0023907074', 'AT', 'Active', '10/27/2027'], ['CMA015', 'KNKA219', 'Verizon Wireless (VAW) LLC', '0003800307', 'CL', 'Active', '10/01/2024'], ['CMA015', 'KNKA247', 'AT&T Mobility Spectrum LLC', '0014980726', 'CL', 'Active', '10/01/2024'], ['CMA015', 'KNKR295', 'DELTA CELLULAR PARTNERS I', '', 'CL', 'Terminated', ''], ['CMA015', 'KNKR320', 'ALLTEL Corporation', '0002942159', 'CL', 'Active', '04/02/2028'], ['CMA015', 'L000007696', 'Game Day Entertainment LLC', '0019860683', 'WZ', 'Expired', '02/14/2011'], ['CMA015', 'WPOI246', 'McElroy Electronics Corporation', '0003623725', 'CL', 'Terminated', '01/19/2009'], ['CMA015', 'WPOI462', 'McElroy Electronics Corporation', '0003623725', 'CL', 'Canceled', '02/25/2009'], ['CMA015', 'WPWV436', 'AT&T Mobility Spectrum LLC', '0014980726', 'WZ', 'Active', '06/13/2019'], ['CMA015', 'WQGD675', 'Cellco Partnership', '0003290673', 'AW', 'Active', '12/18/2021'], ['CMA015', 'WQJU435', 'AT&T Mobility Spectrum LLC', '0014980726', 'WY', 'Active', '06/13/2019'], ['CMA015', 'WQWQ992', 'SNR Wireless LicenseCo, LLC', '0023907074', 'AT', 'Active', '10/27/2027'], ['CMA024', 'KNKA223', 'New Cingular Wireless PCS, LLC', '0003291192', 'CL', 'Active', '10/01/2023'], ['CMA024', 'KNKA337', 'Verizon Wireless (VAW) LLC', '0003800307', 'CL', 'Active', '02/09/2026'], ['CMA024', 'KNKR207', 'Cellco Partnership', '0003290673', 'CL ...

# %% [markdown]
# ### amend 3 // FIX IT incorrectly caching data :(

# %%
# read each line of file in as list

with open('search-cache/csv/amend_CMA002_317.csv', 'r') as f:
    impt = f.readline()

# %%
! ls 'search-cache/csv'
# Out:
# amend_CMA002_317.csv    amend_CMA318_CMA722.csv

# %%
import re

test = impt.replace('","', '\n')
test = test.replace('\"','')

# %%
test_row = re.search('(?:\[)(.+)(?:\]\\n)', test)[1]

# %%
test = test.replace("\'","")

# %%
test_row2 = list(test.split(sep='\n'))[0]

# %%
split = test_row.split(",")

# %%
list(split)[0]
# Out:
# 'CMA002'

# %%
with open('search-cache/csv/amend_CMA002_317.csv', 'r') as f:
    lst_cma_tables = f.readlines()

# %%
table_str = []

for table in lst_cma_tables:
    replaced_str = table.replace('","', '\n').replace('\"','').replace("\'","")
    table_str += replaced_str.split(sep='\n')
# Out:
# ['[CMA002, KNKA209, Los Angeles SMSA Limited Partnership, 0002963817, CL, Active, 10/01/2024]',
#  '[CMA002, KNKA351, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2027]',
#  '[CMA002, KNKR294, FOLDEN, GENE A, , CL, Terminated, ]',
#  '[CMA002, KNKR313, LOS ANGELES SMSA LIMITED PARTNERSHIP, 0002963817, CL, Canceled, 09/24/2007]',
#  '[CMA002, L000009285, AirTouch Cellular, 0006146468, WY, Canceled, 06/13/2019]',
#  '[CMA002, L000010911, Cellco Partnership, 0003290673, AW, Canceled, 01/25/2014]',
#  '[CMA002, L000010913, New Cingular Wireless PCS, LLC, 0003291192, WY, Canceled, 01/25/2014]',
#  '[CMA002, L000015067, Screened Images, Inc., 0021044003, CL, Active, 10/01/2027]',
#  '[CMA002, L000023743, Screened Images, Inc., 0021044003, AW, Active, 11/29/2021]',
#  '[CMA002, WPOI449, Los Angeles SMSA Limited Partnership-AirTouch Cellular, 0002963817, CL, Canceled, 02/18/2009]',
#  '[CMA002, WPWU990, AT&T Mobility LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA002, WQGA742, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA002, WQJQ721, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA002, WQSH611, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA002, WQWQ746, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '',
#  '[CMA014, KNKA232, Cellco Partnership, 0003290673, CL, Active, 10/01/2024]',
#  '[CMA014, KNKA242, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2023]',
#  '[CMA014, L000010153, Tecore Government Services, LLC, 0019878172, AW, Active, 12/18/2021]',
#  '[CMA014, L000011612, Tecore Government Services, LLC, 0019878172, CL, Expired, 10/01/2014]',
#  '[CMA014, L000015304, Tecore Government Services, LLC, 0019878172, CL, Active, 10/01/2024]',
#  '[CMA014, L000017021, Tecore Government Services, LLC, 0019878172, WZ, Active, 06/13/2019]',
#  '[CMA014, L000017022, Tecore Government Services, LLC, 0019878172, WY, Active, 06/13/2019]',
#  '[CMA014, L000017299, Tecore Government Services, LLC, 0019878172, CL, Active, 10/01/2023]',
#  '[CMA014, WPWU996, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA014, WQGD674, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 12/18/2021]',
#  '[CMA014, WQJU434, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA014, WQWQ991, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA015, KNKA219, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 10/01/2024]',
#  '[CMA015, KNKA247, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2024]',
#  '[CMA015, KNKR295, DELTA CELLULAR PARTNERS I, , CL, Terminated, ]',
#  '[CMA015, KNKR320, ALLTEL Corporation, 0002942159, CL, Active, 04/02/2028]',
#  '[CMA015, L000007696, Game Day Entertainment LLC, 0019860683, WZ, Expired, 02/14/2011]',
#  '[CMA015, WPOI246, McElroy Electronics Corporation, 0003623725, CL, Terminated, 01/19/2009]',
#  '[CMA015, WPOI462, McElroy Electronics Corporation, 0003623725, CL, Canceled, 02/25/2009]',
#  '[CMA015, WPWV436, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA015, WQGD675, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA015, WQJU435, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA015, WQWQ992, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA024, KNKA223, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 10/01/2023]',
#  '[CMA024, KNKA337, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 02/09/2026]',
#  '[CMA024, KNKR207, Cellco Partnership, 0003290673, CL, Active, 10/01/2025]',
#  '[CMA024, WPOI251, Dobson Cellular of Kansas/Missouri Inc  CELLULARONE, 0001697077, CL, Canceled, 01/25/2009]',
#  '[CMA024, WPOI261, AWZ Cellular Corporation, 0002148682, CL, Canceled, 01/25/2009]',
#  '[CMA024, WPOI418, Missouri RSA No 7 Limited Partnership Dba/Mid Missouri Cellular, 0002535276, CL, Canceled, 02/04/2009]',
#  '[CMA024, WPWV203, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA024, WPZP958, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 10/01/2025]',
#  '[CMA024, WQGD677, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 12/18/2021]',
#  '[CMA024, WQJU443, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA024, WQWQ995, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA026, KNKA205, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 10/01/2024]',
#  '[CMA026, KNKA303, ALLTEL Corporation, 0002942159, CL, Active, 02/09/2026]',
#  '[CMA026, KNKR208, Commnet of Arizona, LLC, 0009291220, CL, Active, 10/01/2025]',
#  '[CMA026, L000005002, James H. Wanserski, Hold Separate Trustee, 0018360701, CL, Canceled, 12/30/2009]',
#  '[CMA026, L000018826, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 09/15/2016]',
#  '[CMA026, L000018836, New Cingular Wireless PCS, LLC, 0003291192, AW, Canceled, 09/15/2016]',
#  '[CMA026, WPOI420, Southwestco Wireless Limited Partnership, 0003290525, CL, Canceled, 02/04/2009]',
#  '[CMA026, WPOK974, Southwestco Wireless Limited Partnership, 0003290525, CL, Canceled, 10/15/2009]',
#  '[CMA026, WPOK988, Gila River Cellular General Partnership, 0001607183, CL, Canceled, 10/01/2005]',
#  '[CMA026, WPWV204, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA026, WQGA745, T-Mobile License LLC, 0001565449, AW, Canceled, 11/29/2021]',
#  '[CMA026, WQJU445, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA026, WQVP373, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '[CMA026, WQXK658, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA026, WQXQ398, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 11/29/2021]',
#  '',
#  '[CMA028, KNKA208, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2023]',
#  '[CMA028, KNKA216, GTE MOBILNET OF INDIANA LIMITED PARTNERSHIP, 0003579364, CL, Active, 10/01/2024]',
#  '[CMA028, L000020043, Shawntech Communications, Inc, 0018990028, WZ, Canceled, 12/31/2016]',
#  '[CMA028, L000020052, Shawntech Communications, Inc, 0018990028, AW, Canceled, 12/31/2016]',
#  '[CMA028, L000020057, Shawntech Communications, Inc, 0018990028, WY, Canceled, 12/31/2016]',
#  '[CMA028, L000024819, Shawntech Communications, Inc, 0018990028, WZ, Active, 06/13/2019]',
#  '[CMA028, L000024830, Shawntech Communications, Inc, 0018990028, AW, Active, 07/31/2020]',
#  '[CMA028, L000024838, Shawntech Communications, Inc, 0018990028, WY, Active, 06/13/2019]',
#  '[CMA028, L000024843, Shawntech Communications, Inc, 0018990028, AT, Active, 07/31/2020]',
#  '[CMA028, WPWV205, AT&T Mobility LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA028, WQGD481, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA028, WQJU447, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA028, WQVN882, AT&T Mobility Spectrum LLC, 0014980726, AT, Active, 04/08/2027]',
#  '',
#  '[CMA029, KNKA224, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2023]',
#  '[CMA029, KNKA352, ALLTEL Corporation, 0002942159, CL, Active, 05/15/2025]',
#  '[CMA029, KNKR209, ALLTEL Corporation, 0002942159, CL, Active, 10/01/2025]',
#  '[CMA029, L000009685, T-Mobile License LLC, 0001565449, AW, Expired, 05/15/2012]',
#  '[CMA029, L000010530, T-Mobile License LLC, 0001565449, AW, Expired, 02/13/2013]',
#  '[CMA029, L000022013, CellBlox Acquisitions, LLC, 0024202053, WZ, Active, 06/13/2019]',
#  '[CMA029, L000022014, CellBlox Acquisitions, LLC, 0024202053, AW, Active, 12/18/2021]',
#  '[CMA029, L000022015, CellBlox Acquisitions, LLC, 0024202053, WY, Active, 06/13/2019]',
#  '[CMA029, L000022977, Cellco Partnership, 0003290673, AW, Canceled, 01/01/2018]',
#  '[CMA029, L000030956, CellBlox Acquisitions, LLC, 0024202053, AW, Active, 12/18/2021]',
#  '[CMA029, WPWV206, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA029, WQGD678, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA029, WQJU448, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA029, WQWQ997, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA039, KNKA259, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 05/15/2025]',
#  '[CMA039, KNKA376, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2026]',
#  '[CMA039, KNKR211, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 10/01/2025]',
#  '[CMA039, KNKR281, WYNDOM CELLULAR CORPORATION, , CL, Terminated, ]',
#  '[CMA039, L000009978, T-Mobile License LLC, 0001565449, AW, Canceled, 02/28/2013]',
#  '[CMA039, WPWV488, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA039, WQGB278, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA039, WQJU456, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA039, WQTK392, Commnet of Nevada, LLC, 0018122879, CL, Terminated, 02/21/2024]',
#  '[CMA039, WQVP374, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '',
#  '[CMA041, KNKA262, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2024]',
#  '[CMA041, KNKA343, Cellco Partnership, 0003290673, CL, Active, 11/29/2026]',
#  '[CMA041, KNKR270, LONESOME DOVE CELLULAR, LTD., , CL, Canceled, 10/01/2005]',
#  '[CMA041, L000009671, T-Mobile License LLC, 0001565449, AW, Canceled, 04/14/2013]',
#  '[CMA041, L000010899, New Cingular Wireless PCS, LLC, 0003291192, WZ, Canceled, 02/20/2014]',
#  '[CMA041, L000011548, Cellco Partnership, 0003290673, AW, Canceled, 11/12/2014]',
#  '[CMA041, WPZL282, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA041, WQGD680, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA041, WQJU458, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA041, WQWQ757, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '',
#  '[CMA045, KNKA296, OKLAHOMA CITY SMSA LIMITED PARTNERSHIP, 0001658392, CL, Active, 10/01/2024]',
#  '[CMA045, KNKA298, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 05/15/2025]',
#  '[CMA045, KNKA369, ALLTEL Corporation, 0002942159, CL, Active, 10/01/2025]',
#  '[CMA045, KNKR212, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 04/02/2026]',
#  '[CMA045, L000010919, New Cingular Wireless PCS, LLC, 0003291192, WY, Canceled, 01/25/2014]',
#  '[CMA045, WPWV214, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA045, WQEG235, ALLTEL Newco LLC, 0012284394, CL, Canceled, 06/12/2007]',
#  '[CMA045, WQGA748, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 11/29/2021]',
#  '[CMA045, WQJQ727, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA045, WQXW450, Advantage Spectrum, L.P., 0023909104, AT, Active, 07/05/2028]',
#  '',
#  '[CMA053, KNKA238, Bell Atlantic Mobile Systems of Allentown, Inc., 0003301512, CL, Active, 05/15/2025]',
#  '[CMA053, KNKA294, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2025]',
#  '[CMA053, KNKR214, STEP 10 CELLULAR PARTNERS, , CL, Terminated, ]',
#  '[CMA053, L000008983, T-Mobile License LLC, 0001565449, AW, Canceled, 05/04/2013]',
#  '[CMA053, L000010396, Cellco Partnership, 0003290673, AW, Canceled, 12/06/2013]',
#  '[CMA053, WPYZ852, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA053, WQGD681, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 12/18/2021]',
#  '[CMA053, WQJU468, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA053, WQON841, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA053, WQWR203, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA071, KNKA293, ALLTEL Corporation, 0002942159, CL, Active, 02/09/2026]',
#  '[CMA071, KNKA358, Cellco Partnership, 0003290673, CL, Active, 05/15/2025]',
#  '[CMA071, L000010954, New Cingular Wireless PCS, LLC, 0003291192, WY, Canceled, 01/25/2014]',
#  '[CMA071, L000011242, AT&T Mobility Spectrum LLC, 0014980726, WY, Canceled, 06/13/2019]',
#  '[CMA071, L000033497, Shawntech Communications, Inc, 0018990028, WY, Active, 06/13/2019]',
#  '[CMA071, L000033632, Shawntech Communications, Inc, 0018990028, WZ, Active, 06/13/2019]',
#  '[CMA071, L000033638, Shawntech Communications, Inc, 0018990028, AW, Active, 11/29/2021]',
#  '[CMA071, WPWU933, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA071, WQGA754, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 11/29/2021]',
#  '[CMA071, WQJQ731, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA071, WQWR207, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA074, KNKA301, FRESNO MSA LIMITED PARTNERSHIP, 0001842954, CL, Active, 02/09/2026]',
#  '[CMA074, KNKA366, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2027]',
#  '[CMA074, KNKR215, Fresno MSA Limited Partnership, 0001842954, CL, Active, 10/01/2025]',
#  '[CMA074, L000014758, Cellco Partnership, 0003290673, AW, Canceled, 09/09/2015]',
#  '[CMA074, L000015064, Screened Images, Inc., 0021044003, CL, Active, 10/01/2027]',
#  '[CMA074, L000024631, Screened Images, Inc., 0021044003, AW, Active, 11/29/2021]',
#  '[CMA074, WPWV220, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA074, WQGA755, T-Mobile License LLC, 0001565449, AW, Active, 11/29/2021]',
#  '[CMA074, WQJU485, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA074, WQVQ455, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '',
#  '[CMA077, KNKA286, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 05/15/2025]',
#  '[CMA077, KNKA340, ALLTEL Corporation, 0002942159, CL, Active, 02/09/2026]',
#  '[CMA077, KNKR216, AB FILLINS, 0006403174, CL, Terminated, 10/01/2005]',
#  '[CMA077, KNKR292, ALLTEL Corporation, 0002942159, CL, Active, 12/03/2026]',
#  '[CMA077, L000005001, James H. Wanserski, Hold Separate Trustee, 0018360701, CL, Canceled, 12/30/2009]',
#  '[CMA077, L000005005, James H. Wanserski, Hold Separate Trustee, 0018360701, CL, Canceled, 12/30/2009]',
#  '[CMA077, L000009988, T-Mobile License LLC, 0001565449, AW, Canceled, 01/31/2013]',
#  '[CMA077, L000031855, Commnet Four Corners LLC, 0009572884, WY, Canceled, 06/13/2019]',
#  '[CMA077, L000031987, Commnet Four Corners LLC, 0009572884, WY, Active, 06/13/2019]',
#  '[CMA077, WPWV221, AT&T Mobility LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA077, WQGB293, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA077, WQJU488, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA077, WQVN884, AT&T Mobility Spectrum LLC, 0014980726, AT, Active, 04/08/2027]',
#  '',
#  '[CMA081, KNKA258, Cellco Partnership, 0003290673, CL, Active, 05/15/2025]',
#  '[CMA081, KNKA321, ALLTEL Corporation, 0002942159, CL, Active, 02/09/2026]',
#  '[CMA081, KNKR218, Proximiti Mobility,Inc., 0019124619, CL, Canceled, 10/01/2025]',
#  '[CMA081, L000005000, James H. Wanserski, Hold Separate Trustee, 0018360701, CL, Canceled, 12/30/2009]',
#  '[CMA081, L000008985, Cricket Communications, Inc., 0010202521, AW, Canceled, 05/04/2013]',
#  '[CMA081, L000009660, Cricket License Company, LLC, 0018402123, AW, Canceled, 04/14/2013]',
#  '[CMA081, L000010081, T-Mobile License LLC, 0001565449, AW, Canceled, 06/30/2013]',
#  '[CMA081, WPXD985, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA081, WQGB294, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA081, WQJU492, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA081, WQON992, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '',
#  '[CMA086, KNKA272, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 05/15/2025]',
#  '[CMA086, KNKA332, ALLTEL Corporation, 0002942159, CL, Active, 02/09/2026]',
#  '[CMA086, KNKR219, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 05/14/2026]',
#  '[CMA086, L000005003, James H. Wanserski, Hold Separate Trustee, 0018360701, CL, Canceled, 12/30/2009]',
#  '[CMA086, L000008986, Cricket Communications, Inc., 0010202521, AW, Canceled, 05/04/2013]',
#  '[CMA086, L000009661, Cricket License Company, LLC, 0018402123, AW, Canceled, 04/14/2013]',
#  '[CMA086, L000010082, T-Mobile License LLC, 0001565449, AW, Canceled, 06/30/2013]',
#  '[CMA086, L000010754, Smith Bagley, Inc., 0002154706, WY, Expired, 01/20/2014]',
#  '[CMA086, L000031856, Commnet Four Corners LLC, 0009572884, WY, Canceled, 06/13/2019]',
#  '[CMA086, L000031988, Commnet Four Corners LLC, 0009572884, WY, Active, 06/13/2019]',
#  '[CMA086, WPWV223, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA086, WQGB296, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA086, WQJU497, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA086, WQON993, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA086, WQRK784, Smith Bagley, Inc., 0002154706, WY, Active, 06/13/2019]',
#  '[CMA086, WQWR210, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA089, KNKA255, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2024]',
#  '[CMA089, KNKA357, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 02/09/2026]',
#  '[CMA089, KNKR220, ALLTEL Corporation, 0002942159, CL, Active, 10/01/2025]',
#  '[CMA089, L000032496, AT&T Mobility Spectrum LLC, 0014980726, WZ, Canceled, 06/13/2019]',
#  '[CMA089, WPOI445, Liberty Cellular Inc, 0002320877, CL, Canceled, 02/16/2009]',
#  '[CMA089, WPOI457, Wichita SMSA Limited Partnership, 0001658657, CL, Canceled, 02/23/2009]',
#  '[CMA089, WPZL280, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA089, WQGA756, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA089, WQJU500, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA089, WQWR211, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA090, KNKA299, Charleston-North Charleston MSA Limited Partnership, 0002531291, CL, Active, 05/15/2025]',
#  '[CMA090, KNKA327, Charleston-North Charleston MSA Limited Partnership, 0002531291, CL, Active, 01/22/2028]',
#  '[CMA090, L000009515, Shawntech Communications, Inc., 0018990028, CL, Expired, 05/15/2017]',
#  '[CMA090, L000009516, Shawntech Communications, Inc., 0018990028, CL, Canceled, 01/22/2018]',
#  '[CMA090, L000012416, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 05/15/2015]',
#  '[CMA090, L000013163, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 05/15/2015]',
#  '[CMA090, WQBQ594, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA090, WQGD640, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA090, WQJU501, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA090, WQJY534, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '',
#  '[CMA097, KNKA405, FRESNO MSA LIMITED PARTNERSHIP, 0001842954, CL, Active, 11/29/2026]',
#  '[CMA097, KNKA584, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2027]',
#  '[CMA097, KNKR221, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2025]',
#  '[CMA097, KNKR222, Fresno MSA Limited Partnership, 0001842954, CL, Active, 10/01/2025]',
#  '[CMA097, L000015062, Screened Images, Inc., 0021044003, CL, Active, 10/01/2027]',
#  '[CMA097, L000015065, Screened Images, Inc., 0021044003, CL, Active, 10/01/2025]',
#  '[CMA097, L000023741, Screened Images, Inc., 0021044003, AW, Active, 11/29/2021]',
#  '[CMA097, L000024648, Screened Images, Inc., 0021044003, AT, Active, 04/08/2027]',
#  '[CMA097, WPWV227, AT&T Mobility LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA097, WQGB298, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA097, WQJU507, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA097, WQVP378, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '',
#  '[CMA098, KNKA419, GTE WIRELESS OF THE MIDWEST INCORPORATED, 0003578580, CL, Active, 01/22/2028]',
#  '[CMA098, KNKA456, USCOC OF GREATER IOWA, LLC, 0018420067, CL, Active, 01/22/2028]',
#  '[CMA098, L000002587, Central Scott Telephone Company, Inc., 0003722121, WZ, Canceled, 02/17/2019]',
#  '[CMA098, L000032240, Cover 2, LLC, 0025959776, WZ, Canceled, 06/13/2019]',
#  '[CMA098, L000032264, Cover 2, LLC, 0025959776, WY, Canceled, 06/13/2019]',
#  '[CMA098, L000032549, Cover 2, LLC, 0025959776, WZ, Active, 06/13/2019]',
#  '[CMA098, L000032563, Cover 2, LLC, 0025959776, WY, Active, 06/13/2019]',
#  '[CMA098, L000032568, Cover 2, LLC, 0025959776, WZ, Active, 06/13/2019]',
#  '[CMA098, L000032579, Cover 2, LLC, 0025959776, WY, Active, 06/13/2019]',
#  '[CMA098, L000032581, Cover 2, LLC, 0025959776, WZ, Active, 06/13/2019]',
#  '[CMA098, L000032590, Cover 2, LLC, 0025959776, WY, Active, 06/13/2019]',
#  '[CMA098, L000032592, Cover 2, LLC, 0025959776, WZ, Active, 06/13/2019]',
#  '[CMA098, L000032598, Cover 2, LLC, 0025959776, WY, Active, 06/13/2019]',
#  '[CMA098, L000032600, Cover 2, LLC, 0025959776, WZ, Active, 06/13/2019]',
#  '[CMA098, L000032606, Cover 2, LLC, 0025959776, WY, Active, 06/13/2019]',
#  '[CMA098, WPWV384, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA098, WQGA877, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 11/29/2021]',
#  '[CMA098, WQJU508, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA098, WQXW451, Advantage Spectrum, L.P., 0023909104, AT, Active, 07/05/2028]',
#  '',
#  '[CMA101, KNKA389, GTE MOBILNET OF SOUTH TEXAS LIMITED PARTNERSHIP, 0003579406, CL, Active, 11/29/2026]',
#  '[CMA101, KNKA454, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 01/22/2028]',
#  '[CMA101, L000010274, Shawntech Communications, Inc, 0018990028, CL, Canceled, 11/29/2026]',
#  '[CMA101, L000010466, Shawntech Communications, Inc, 0018990028, CL, Canceled, 01/22/2018]',
#  '[CMA101, L000026544, CellBlox Acquisitions, LLC, 0024202053, WZ, Active, 06/13/2019]',
#  '[CMA101, L000026547, CellBlox Acquisitions, LLC, 0024202053, WY, Active, 06/13/2019]',
#  '[CMA101, L000032203, CellBlox Acquisitions, LLC, 0024202053, AT, Active, 04/08/2027]',
#  '[CMA101, WPWU927, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA101, WQGD663, Command Connect, LLC, 0001711837, AW, Active, 12/18/2021]',
#  '[CMA101, WQJU511, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA101, WQVP379, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '',
#  '[CMA106, KNKA403, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2025]',
#  '[CMA106, KNKA799, Jackson Cellular Telephone Co., Inc., 0003985371, CL, Active, 11/27/2028]',
#  '[CMA106, KNKR224, SKY CELL, LTD., , CL, Terminated, 06/03/2007]',
#  '[CMA106, L000011531, Cellco Partnership, 0003290673, AW, Canceled, 11/12/2014]',
#  '[CMA106, L000016073, Screened Images, Inc., 0021044003, CL, Active, 10/01/2025]',
#  '[CMA106, L000032781, Screened Images, Inc., 0021044003, WZ, Active, 06/13/2019]',
#  '[CMA106, L000032782, Screened Images, Inc., 0021044003, WY, Active, 06/13/2019]',
#  '[CMA106, L000033088, Screened Images, Inc., 0021044003, AW, Active, 11/29/2021]',
#  '[CMA106, WPWU951, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA106, WQGA759, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA106, WQJU515, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA106, WQWQ769, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '',
#  '[CMA113, KNKA414, MADISON SMSA LIMITED PARTNERSHIP, 0002842060, CL, Active, 10/01/2026]',
#  '[CMA113, KNKA612, MADISON CELLULAR TELEPHONE COMPANY, 0001574540, CL, Active, 11/29/2026]',
#  '[CMA113, L000023040, Michigan Wireless, LLC, 0015680374, WZ, Canceled, 06/01/2017]',
#  '[CMA113, L000023041, Michigan Wireless, LLC, 0015680374, WY, Canceled, 06/01/2017]',
#  '[CMA113, L000023705, Michigan Wireless, LLC, 0015680374, WZ, Canceled, 06/13/2019]',
#  '[CMA113, L000023706, Michigan Wireless, LLC, 0015680374, WY, Canceled, 06/13/2019]',
#  '[CMA113, L000023707, Michigan Wireless, LLC, 0015680374, WZ, Active, 06/13/2019]',
#  '[CMA113, L000023708, Michigan Wireless, LLC, 0015680374, WY, Active, 06/13/2019]',
#  '[CMA113, L000023709, Michigan Wireless, LLC, 0015680374, WZ, Active, 06/13/2019]',
#  '[CMA113, L000023710, Michigan Wireless, LLC, 0015680374, WY, Active, 06/13/2019]',
#  '[CMA113, L000023711, Michigan Wireless, LLC, 0015680374, WZ, Active, 06/13/2019]',
#  '[CMA113, L000023712, Michigan Wireless, LLC, 0015680374, WY, Active, 06/13/2019]',
#  '[CMA113, L000023713, Michigan Wireless, LLC, 0015680374, WZ, Active, 06/13/2019]',
#  '[CMA113, L000023714, Michigan Wireless, LLC, 0015680374, WY, Active, 06/13/2019]',
#  '[CMA113, L000023715, Michigan Wireless, LLC, 0015680374, WZ, Active, 06/13/2019]',
#  '[CMA113, L000023716, Michigan Wireless, LLC, 0015680374, WY, Active, 06/13/2019]',
#  '[CMA113, WPWV438, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA113, WQGV756, UNITED STATES CELLULAR OPERATING COMPANY LLC, 0002844595, AW, Active, 04/30/2022]',
#  '[CMA113, WQJU522, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA113, WQVP249, Cellco Partnership, 0003290673, AT, Active, 04/08/2027]',
#  '',
#  '[CMA127, KNKA491, ALLTEL Corporation, 0002942159, CL, Active, 01/22/2028]',
#  '[CMA127, KNKA696, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2027]',
#  '[CMA127, KNKR227, LEMONS, JOHN K. / DELTA TRUST PARTNERSHIP, , CL, Terminated, ]',
#  '[CMA127, L000005012, James H. Wanserski, Hold Separate Trustee, 0018360701, CL, Canceled, 12/30/2009]',
#  '[CMA127, L000009767, T-Mobile License LLC, 0001565449, AW, Canceled, 05/31/2013]',
#  '[CMA127, L000011556, Cellco Partnership, 0003290673, AW, Canceled, 11/12/2014]',
#  '[CMA127, WQBQ596, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA127, WQGA688, Cellular South Licenses, LLC, 0020434767, AW, Active, 11/29/2021]',
#  '[CMA127, WQJU534, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA127, WQPX404, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA127, WQWQ775, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '',
#  '[CMA128, KNKA437, ALLTEL Corporation, 0002942159, CL, Active, 01/22/2028]',
#  '[CMA128, KNKA444, MCALLEN-EDINBURG-MISSION SMSA LIMITED PARTNERSHIP, 0001658467, CL, Active, 10/01/2027]',
#  '[CMA128, KNKR228, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2025]',
#  '[CMA128, L000008987, Cricket Communications, Inc., 0010202521, AW, Canceled, 05/04/2013]',
#  '[CMA128, L000009687, T-Mobile License LLC, 0001565449, AW, Canceled, 04/02/2013]',
#  '[CMA128, L000018802, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 09/15/2016]',
#  '[CMA128, L000018804, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 09/15/2016]',
#  '[CMA128, WPYZ861, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA128, WQGB308, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA128, WQJU535, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA128, WQON994, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA128, WQVP380, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '',
#  '[CMA141, KNKA439, CommNet Cellular Inc., 0017329715, CL, Active, 01/22/2028]',
#  '[CMA141, KNKA504, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 01/22/2028]',
#  '[CMA141, KNKR230, ACC MINNESOTA LICENSE LLC, , CL, Canceled, 10/01/2005]',
#  '[CMA141, L000032823, AT&T Mobility Spectrum, LLC, 0014980726, AW, Canceled, 09/22/2019]',
#  '[CMA141, WPTH838, ACC Minnesota License LLC, , CL, Expired, 04/02/2002]',
#  '[CMA141, WPWU966, Nsight Spectrum, LLC, 0020519138, WZ, Active, 06/13/2019]',
#  '[CMA141, WQGI506, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 01/29/2022]',
#  '[CMA141, WQHP239, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA141, WQJU545, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA141, WQVP250, Cellco Partnership, 0003290673, AT, Active, 04/08/2027]',
#  '',
#  '[CMA152, KNKA708, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2027]',
#  '[CMA152, KNKA744, PORTLAND CELLULAR PARTNERSHIP, , CL, Canceled, 10/01/1997]',
#  '[CMA152, KNKA824, NORTHEAST CELLULAR TELEPHONE COMPANY, L.P., 0003682804, CL, Expired, 10/01/2004]',
#  '[CMA152, KNKQ459, Bell Atlantic Mobile Systems of Allentown, Inc., 0003301512, CL, Active, 01/15/2029]',
#  '[CMA152, L000026880, AT&T Mobility Spectrum LLC, 0014980726, WY, Canceled, 08/21/2018]',
#  '[CMA152, L000026884, Maine RSA #1, Inc., 0002841963, WZ, Canceled, 08/21/2018]',
#  '[CMA152, WPZA245, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA152, WQGD493, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA152, WQJU552, MAINE RSA #1, INC., 0002841963, WY, Active, 06/13/2019]',
#  '[CMA152, WQWR226, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA161, KNKA421, LUBBOCK SMSA LIMITED PARTNERSHIP, 0001650787, CL, Active, 10/01/2026]',
#  '[CMA161, KNKA530, ALLTEL Corporation, 0002942159, CL, Active, 11/29/2026]',
#  '[CMA161, L000008727, WWC Texas RSA Limited Partnership, 0001565563, WY, Canceled, 06/13/2019]',
#  '[CMA161, L000010473, NTCH, Inc., 0005575048, WY, Canceled, 01/31/2014]',
#  '[CMA161, L000010526, WWC License L.L.C., 0018437699, AW, Canceled, 01/27/2014]',
#  '[CMA161, L000011274, Yodeler Wireless LLC, 0022636948, WY, Expired, 12/30/2014]',
#  '[CMA161, L000013863, Yodeler Wireless LLC, 0022636948, WY, Canceled, 12/30/2015]',
#  '[CMA161, WPOI484, KETS Partnership, 0001568682, CL, Canceled, 03/19/2009]',
#  '[CMA161, WPWV543, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA161, WQGD463, ALLTEL Corporation, 0002942159, AW, Active, 12/18/2021]',
#  '[CMA161, WQJQ734, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA161, WQVP385, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '',
#  '[CMA162, KNKA430, MCALLEN-EDINBURG-MISSION SMSA LIMITED PARTNERSHIP, 0001658467, CL, Active, 10/01/2027]',
#  '[CMA162, KNKA651, ALLTEL Corporation, 0002942159, CL, Active, 01/22/2028]',
#  '[CMA162, KNKR236, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2025]',
#  '[CMA162, L000008988, Cricket Communications, Inc., 0010202521, AW, Canceled, 05/04/2013]',
#  '[CMA162, L000009688, T-Mobile License LLC, 0001565449, AW, Canceled, 04/02/2013]',
#  '[CMA162, L000018803, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 09/15/2016]',
#  '[CMA162, L000018805, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 09/15/2016]',
#  '[CMA162, WPYZ866, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA162, WQGB317, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA162, WQJU557, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA162, WQON995, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA162, WQVP386, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '',
#  '[CMA165, KNKA476, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2026]',
#  '[CMA165, KNKA614, ALLTEL Corporation, 0002942159, CL, Active, 01/22/2028]',
#  '[CMA165, L000016553, Pine Cellular Phones, Inc., 0012882643, WZ, Terminated, 04/03/2016]',
#  '[CMA165, L000016554, Pine Cellular Phones, Inc., 0012882643, WY, Terminated, 04/03/2016]',
#  '[CMA165, L000017992, Pine Cellular Phones, Inc., 0012882643, WZ, Active, 06/13/2019]',
#  '[CMA165, L000017996, Pine Cellular Phones, Inc., 0012882643, WY, Active, 06/13/2019]',
#  '[CMA165, L000018005, Pine Cellular Phones, Inc., 0012882643, WZ, Canceled, 04/03/2016]',
#  '[CMA165, L000018006, Pine Cellular Phones, Inc., 0012882643, WY, Canceled, 04/03/2016]',
#  '[CMA165, WPOI435, Southwestern Bell Wireless Inc, 0001659226, CL, Canceled, 02/10/2009]',
#  '[CMA165, WPYZ867, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA165, WQGT853, Cellco Partnership, 0003290673, AW, Active, 04/16/2022]',
#  '[CMA165, WQIZ549, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA165, WQWR230, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA166, KNKA436, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 01/22/2028]',
#  '[CMA166, KNKA770, Cellco Partnership, 0003290673, CL, Active, 11/27/2028]',
#  '[CMA166, L000004251, W. Stephen Cannon, Management Trustee, 0017119025, CL, Expired, 12/30/2009]',
#  '[CMA166, L000006248, W. Stephen Cannon, Management Trustee, 0017119025, CL, Canceled, 12/31/2010]',
#  '[CMA166, L000032494, New Cingular Wireless PCS, LLC, 0003291192, WY, Canceled, 06/13/2019]',
#  '[CMA166, L000033576, Shawntech Communications, Inc, 0018990028, WZ, Active, 06/13/2019]',
#  '[CMA166, WPWU981, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA166, WQGB254, Carolina West Wireless, Inc., 0001940022, AW, Active, 11/29/2021]',
#  '[CMA166, WQIZ412, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA166, WQVP387, T-Mobile License LLC, 0001565449, AT, Active, 04/08/2027]',
#  '',
#  '[CMA168, KNKA432, ALLTEL Corporation, 0002942159, CL, Active, 11/29/2026]',
#  '[CMA168, KNKA481, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 01/22/2028]',
#  '[CMA168, L000009999, T-Mobile License LLC, 0001565449, AW, Canceled, 03/31/2013]',
#  '[CMA168, L000020831, Cellblox Acquisitions, LLC, 0024202053, WZ, Active, 06/13/2019]',
#  '[CMA168, L000020834, Cellblox Acquisitions, LLC, 0024202053, WY, Active, 06/13/2019]',
#  '[CMA168, L000030952, CellBlox Acquisitions, LLC, 0024202053, AW, Active, 11/29/2021]',
#  '[CMA168, WQBQ602, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA168, WQGB320, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA168, WQJU561, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA168, WQWR231, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA171, KNKA462, SACRAMENTO VALLEY LIMITED PARTNERSHIP, 0002972149, CL, Active, 01/22/2028]',
#  '[CMA171, KNKA516, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2026]',
#  '[CMA171, L000031857, Commnet Four Corners LLC, 0009572884, WY, Canceled, 06/13/2019]',
#  '[CMA171, L000031989, Commnet Four Corners LLC, 0009572884, WY, Active, 06/13/2019]',
#  '[CMA171, L000032498, Commnet Four Corners LLC, 0009572884, WZ, Canceled, 06/13/2019]',
#  '[CMA171, L000032499, Commnet Four Corners LLC, 0009572884, WY, Canceled, 06/13/2019]',
#  '[CMA171, L000032629, Commnet Four Corners LLC, 0009572884, WZ, Active, 06/13/2019]',
#  '[CMA171, L000032630, Commnet Four Corners LLC, 0009572884, WY, Active, 06/13/2019]',
#  '[CMA171, WPOI422, Sacramento-Valley Limited Partnership, 0002972149, CL, Canceled, 02/08/2009]',
#  '[CMA171, WPWV387, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA171, WQGD695, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA171, WQJU562, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA171, WQVP252, Cellco Partnership, 0003290673, AT, Active, 04/08/2027]',
#  '',
#  '[CMA174, KNKA458, Cellco Partnership, 0003290673, CL, Active, 01/22/2028]',
#  '[CMA174, KNKA492, Lafayette MSA Limited Partnership, 0001682509, CL, Active, 10/01/2027]',
#  '[CMA174, L000005937, James H. Wanserski, Trustee, 0018360701, CL, Canceled, 11/01/2010]',
#  '[CMA174, L000017331, AT&T Mobility Spectrum LLC, 0014980726, WZ, Expired, 08/25/2015]',
#  '[CMA174, L000017333, AT&T Mobility Spectrum LLC, 0014980726, WZ, Canceled, 02/25/2016]',
#  '[CMA174, L000022979, Cellco Partnership, 0003290673, AW, Canceled, 01/01/2018]',
#  '[CMA174, WPOL584, Lafayette MSA Limited Partnership, 0001682509, CL, Expired, 01/15/2000]',
#  '[CMA174, WPWV341, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA174, WQGD696, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA174, WQIZ550, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA174, WQWQ782, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '',
#  '[CMA176, KNKA630, Cellco Partnership, 0003290673, CL, Active, 01/22/2028]',
#  '[CMA176, KNKA747, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2027]',
#  '[CMA176, KNKR240, ALPHA PARTNERSHIP P.L.L., , CL, Canceled, 10/01/2005]',
#  '[CMA176, L000010000, T-Mobile License LLC, 0001565449, AW, Canceled, 03/31/2013]',
#  '[CMA176, L000019450, AT&T Mobility Spectrum LLC, 0014980726, WZ, Canceled, 03/03/2017]',
#  '[CMA176, WPOI263, Illinois SMSA Limited Partnership, 0002840718, CL, Canceled, 01/28/2009]',
#  '[CMA176, WPWV467, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA176, WQGB322, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA176, WQLE682, King Street Wireless, LP, 0017169327, WY, Active, 12/30/2019]',
#  '[CMA176, WQVP253, Cellco Partnership, 0003290673, AT, Active, 04/08/2027]',
#  '',
#  '[CMA181, KNKA506, Muskegon Cellular Partnership, 0005412259, CL, Active, 01/22/2028]',
#  '[CMA181, KNKA552, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 01/22/2028]',
#  '[CMA181, L000004651, W. Stephen Cannon, Management Trustee, 0017119025, CL, Terminated, 12/30/2009]',
#  '[CMA181, L000006299, W. Stephen Cannon, Management Trustee, 0017119025, CL, Terminated, 12/31/2010]',
#  '[CMA181, L000007546, AT&T MOBILITY II LLC, 0016982233, CL, Terminated, 12/19/2010]',
#  '[CMA181, L000018017, AT&T Mobility Spectrum LLC, 0014980726, WY, Canceled, 07/26/2016]',
#  '[CMA181, WPZA219, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA181, WQGA804, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]',
#  '[CMA181, WQIZ355, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA181, WQOU737, New Cingular Wireless PCS, LLC, 0003291192, CL, Expired, 04/03/2012]',
#  '[CMA181, WQWQ783, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '',
#  '[CMA185, KNKA497, GTE MOBILNET OF TERRE HAUTE LIMITED PARTNERSHIP, 0003577582, CL, Active, 01/22/2028]',
#  '[CMA185, KNKA762, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2028]',
#  '[CMA185, KNKR269, SOUTHERN INDIANA RSA LIMITED PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA185, L000020048, Shawntech Communications, Inc, 0018990028, WZ, Canceled, 12/31/2016]',
#  '[CMA185, L000020053, Shawntech Communications, Inc, 0018990028, AW, Canceled, 12/31/2016]',
#  '[CMA185, L000020055, Shawntech Communications, Inc, 0018990028, WY, Canceled, 12/31/2016]',
#  '[CMA185, L000024822, Shawntech Communications, Inc, 0018990028, WZ, Active, 06/13/2019]',
#  '[CMA185, L000024831, Shawntech Communications, Inc, 0018990028, AW, Active, 07/31/2020]',
#  '[CMA185, L000024835, Shawntech Communications, Inc, 0018990028, WY, Active, 06/13/2019]',
#  '[CMA185, L000024844, Shawntech Communications, Inc, 0018990028, AT, Active, 07/31/2020]',
#  '[CMA185, WPYZ870, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA185, WQGD498, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA185, WQIZ564, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA185, WQVN889, AT&T Mobility Spectrum LLC, 0014980726, AT, Active, 04/08/2027]',
#  '',
#  '[CMA187, KNKA480, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/01/2019]',
#  '[CMA187, KNKA536, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 01/22/2028]',
#  '[CMA187, KNKR241, Bluff Cellular Partnership, , CL, Canceled, ]',
#  '[CMA187, L000019233, Cellco Partnership, 0003290673, AW, Canceled, 02/11/2017]',
#  '[CMA187, WPRT807, ACS Wireless License Sub, Inc., 0004525325, CL, Expired, 07/25/2001]',
#  '[CMA187, WPTL336, ACS Wireless License Sub, Inc., 0004525325, CL, Canceled, 04/17/2002]',
#  '[CMA187, WPZA246, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA187, WQGD636, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA187, WQJU565, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA187, WQWQ786, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '',
#  '[CMA188, KNKA574, ALLTEL Corporation, 0002942159, CL, Active, 12/30/2026]',
#  '[CMA188, KNKA620, Lubbock SMSA Limited Partnership, 0001650787, CL, Active, 10/01/2026]',
#  '[CMA188, L000008949, WWC License L.L.C., 0018437699, WY, Canceled, 06/13/2019]',
#  '[CMA188, L000010474, NTCH, Inc., 0005575048, WY, Canceled, 01/31/2014]',
#  '[CMA188, L000010527, WWC Texas RSA Limited Partnership, 0001565563, AW, Canceled, 01/27/2014]',
#  '[CMA188, L000011275, Yodeler Wireless LLC, 0022636948, WY, Expired, 12/30/2014]',
#  '[CMA188, L000013864, Yodeler Wireless LLC, 0022636948, WY, Canceled, 12/30/2015]',
#  '[CMA188, WPWV544, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA188, WQGD464, ALLTEL Corporation, 0002942159, AW, Active, 12/18/2021]',
#  '[CMA188, WQJQ735, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '',
#  '[CMA217, KNKA629, GTE MOBILNET OF INDIANA LIMITED PARTNERSHIP, 0003579364, CL, Active, 11/29/2026]',
#  '[CMA217, KNKA806, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2020]',
#  '[CMA217, L000022929, AT&T Mobility Spectrum LLC, 0014980726, WZ, Canceled, 04/26/2017]',
#  '[CMA217, L000022932, AT&T Mobility Spectrum LLC, 0014980726, WY, Canceled, 04/26/2017]',
#  '[CMA217, L000024827, Shawntech Communications, Inc, 0018990028, WZ, Active, 06/13/2019]',
#  '[CMA217, L000024837, Shawntech Communications, Inc, 0018990028, WY, Active, 06/13/2019]',
#  '[CMA217, L000024845, Shawntech Communications, Inc, 0018990028, AT, Active, 07/31/2020]',
#  '[CMA217, WQBQ607, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA217, WQGI512, Cellco Partnership, 0003290673, AW, Active, 01/29/2022]',
#  '[CMA217, WQJQ743, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA217, WQVN892, AT&T Mobility Spectrum LLC, 0014980726, AT, Active, 04/08/2027]',
#  '',
#  '[CMA221, KNKA713, Verizon Wireless (VAW) LLC, 0003800307, CL, Active, 01/22/2028]',
#  '[CMA221, KNKA822, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2021]',
#  '[CMA221, L000000043, IDEAONE TELECOM GROUP, LLC, 0021281381, WZ, Canceled, 01/01/2015]',
#  '[CMA221, L000004946, W. Stephen Cannon, Management Trustee, 0017119025, CL, Expired, 12/30/2009]',
#  '[CMA221, L000006589, W. Stephen Cannon, Management Trustee, 0017119025, CL, Canceled, 12/31/2010]',
#  '[CMA221, L000024240, AT&T Mobility Spectrum LLC, 0014980726, WZ, Canceled, 03/25/2018]',
#  '[CMA221, L000031586, Polar Communications Mutual Aid Corporation, 0003740040, WY, Expired, 02/17/2018]',
#  '[CMA221, L000031588, Polar Communications Mutual Aid Corporation, 0003740040, WY, Canceled, 02/17/2019]',
#  '[CMA221, WPOI272, North Dakota RSA No. 3 Limited Partnership, 0001572429, CL, Canceled, 02/02/2009]',
#  '[CMA221, WPOI274, WWC Holding Co., Inc., 0001569235, CL, Canceled, 02/02/2009]',
#  '[CMA221, WPWV272, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA221, WQGD430, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA221, WQOL881, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 11/10/2021]',
#  '[CMA221, WQVP255, Cellco Partnership, 0003290673, AT, Active, 04/08/2027]',
#  '',
#  '[CMA227, KNKA613, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 11/29/2026]',
#  '[CMA227, KNKA664, ANDERSON CELLTELCO, 0004268926, CL, Active, 01/22/2028]',
#  '[CMA227, L000004261, W. Stephen Cannon, Management Trustee, 0017119025, CL, Expired, 12/30/2009]',
#  '[CMA227, L000006258, W. Stephen Cannon, Management Trustee, 0017119025, CL, Canceled, 12/31/2010]',
#  '[CMA227, L000020144, AT&T Mobility Spectrum, LLC, 0014980726, WY, Canceled, 12/03/2016]',
#  '[CMA227, L000022037, Cellco Partnership, 0003290673, AW, Canceled, 06/18/2017]',
#  '[CMA227, WPYZ877, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA227, WQGD773, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA227, WQHI465, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA227, WQIZ640, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '',
#  '[CMA234, KNKA534, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2026]',
#  '[CMA234, KNKA709, ATHENS CELLULAR, INC., 0001545474, CL, Active, 11/27/2028]',
#  '[CMA234, L000008802, Athens Cellular, Inc., 0001545474, WY, Canceled, 06/13/2019]',
#  '[CMA234, L000010004, T-Mobile License LLC, 0001565449, AW, Canceled, 02/28/2013]',
#  '[CMA234, L000010475, NTCH, Inc., 0005575048, WY, Canceled, 01/31/2014]',
#  '[CMA234, L000011276, Yodeler Wireless LLC, 0022636948, WY, Expired, 12/30/2014]',
#  '[CMA234, L000013865, Yodeler Wireless LLC, 0022636948, WY, Canceled, 12/30/2015]',
#  '[CMA234, WPWV329, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA234, WQGB332, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA234, WQJQ744, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '',
#  '[CMA245, KNKA489, ALLTEL Corporation, 0002942159, CL, Active, 01/22/2028]',
#  '[CMA245, KNKA753, AT&T Mobility Wireless Operations Holdings Inc., 0020078887, CL, Active, 10/01/2028]',
#  '[CMA245, L000011533, Cellco Partnership, 0003290673, AW, Canceled, 11/12/2014]',
#  '[CMA245, WPQN581, Florida RSA #8, Inc., 0002210086, CL, Expired, 12/11/2000]',
#  '[CMA245, WPQZ339, Florida RSA #8, Inc., 0002210086, CL, Expired, 06/12/2001]',
#  '[CMA245, WPSL631, Florida RSA #8, Inc., 0002210086, CL, Expired, 12/12/2001]',
#  '[CMA245, WPTX614, Florida RSA #8, Inc., 0002210086, CL, Canceled, 06/09/2002]',
#  '[CMA245, WQBQ609, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA245, WQGD509, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA245, WQIZ552, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA245, WQWR240, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA246, KNKA543, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 11/29/2026]',
#  '[CMA246, KNKA688, Verizon Wireless of the East LP, 0007609324, CL, Active, 11/27/2028]',
#  '[CMA246, L000004262, W. Stephen Cannon, Management Trustee, 0017119025, CL, Expired, 12/30/2009]',
#  '[CMA246, L000006259, W. Stephen Cannon, Management Trustee, 0017119025, CL, Canceled, 12/31/2010]',
#  '[CMA246, L000007542, AT&T MOBILITY II LLC, 0016982233, CL, Canceled, 12/19/2010]',
#  '[CMA246, L000010908, New Cingular Wireless PCS, LLC, 0003291192, WZ, Canceled, 02/20/2014]',
#  '[CMA246, L000013829, Cellco Partnership, 0003290673, AW, Canceled, 09/26/2015]',
#  '[CMA246, WQBQ610, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA246, WQGA690, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA246, WQIZ480, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA246, WQWR241, SNR Wireless LicenseCo, LLC, 0023907074, AT, Active, 10/27/2027]',
#  '',
#  '[CMA255, KNKA510, ALLTEL Corporation, 0002942159, CL, Active, 01/22/2028]',
#  '[CMA255, KNKA674, Lubbock SMSA Limited Partnership, 0001650787, CL, Active, 10/01/2027]',
#  '[CMA255, L000008728, WWC Texas RSA Limited Partnership, 0001565563, WY, Canceled, 06/13/2019]',
#  '[CMA255, L000010476, NTCH, Inc., 0005575048, WY, Canceled, 01/31/2014]',
#  '[CMA255, L000011277, Yodeler Wireless LLC, 0022636948, WY, Expired, 12/30/2014]',
#  '[CMA255, L000013866, Yodeler Wireless LLC, 0022636948, WY, Canceled, 12/30/2015]',
#  '[CMA255, L000020385, AT&T Mobility Spectrum LLC, 0014980726, AW, Canceled, 09/30/2016]',
#  '[CMA255, WPZA274, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA255, WQGD436, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA255, WQJQ748, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA255, WQVP257, Cellco Partnership, 0003290673, AT, Active, 04/08/2027]',
#  '',
#  '[CMA264, KNKA599, ALLTEL Corporation, 0002942159, CL, Active, 01/22/2028]',
#  '[CMA264, KNKA628, Cellco Partnership, 0003290673, CL, Active, 01/22/2028]',
#  '[CMA264, L000017554, AT&T Mobility Spectrum LLC, 0014980726, WZ, Expired, 08/06/2016]',
#  '[CMA264, L000017574, FTC Communications, LLC, 0004320107, WY, Expired, 08/06/2016]',
#  '[CMA264, L000020191, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
# ...
#  '[CMA299, WQGD779, Union Telephone Company, 0001630201, AW, Active, 12/18/2021]',
#  '[CMA299, WQJQ754, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA299, WQVP262, Cellco Partnership, 0003290673, AT, Active, 04/08/2027]',
#  '',
#  '[CMA306, KNKA411, Tampnet USA LLC, 0024781916, CL, Active, 09/24/2028]',
#  '[CMA306, KNKA412, Tampnet USA LLC, 0024781916, CL, Active, 09/24/2028]',
#  '[CMA306, L000001668, PetroCom License Corporation, 0001711365, CL, Canceled, 01/11/2008]',
#  '[CMA306, L000011377, New Cingular Wireless PCS, LLC, 0003291192, CL, Canceled, 09/24/2018]',
#  '[CMA306, L000011378, New Cingular Wireless PCS, LLC, 0003291192, CL, Canceled, 09/24/2018]',
#  '[CMA306, L000031958, RigNet Satcom, Inc., 0015217680, WZ, Canceled, 06/13/2019]',
#  '[CMA306, L000032954, T-Mobile License LLC, 0001565449, WZ, Active, 06/13/2019]',
#  '[CMA306, WPOL572, Florida RSA #8, Inc., 0002210086, CL, Expired, 06/08/2000]',
#  '[CMA306, WPOL573, Florida RSA #8, Inc., 0002210086, CL, Expired, 06/08/2000]',
#  '[CMA306, WPON293, USCOC of Tallahassee, Inc., , CL, Expired, 09/19/2000]',
#  '[CMA306, WPON294, Florida RSA #8, Inc., 0002210086, CL, Expired, 09/19/2000]',
#  '[CMA306, WPON295, Florida RSA #8, Inc., 0002210086, CL, Expired, 09/19/2000]',
#  '[CMA306, WPON296, USCOC of Tallahassee, Inc., , CL, Canceled, 03/24/2010]',
#  '[CMA306, WPQS497, Florida RSA #8, Inc., 0002210086, CL, Expired, 03/19/2001]',
#  '[CMA306, WPQS498, USCOC of Tallahassee, Inc., , CL, Expired, 03/19/2001]',
#  '[CMA306, WPQS659, USCOC of Tallahassee, Inc., , CL, Terminated, 09/19/2001]',
#  '[CMA306, WPQS770, USCOC of Tallahassee, Inc., , CL, Expired, 03/19/2001]',
#  '[CMA306, WPRY323, USCOC of Tallahassee, Inc., , CL, Canceled, 09/15/2001]',
#  '[CMA306, WPRY324, USCOC of Tallahassee, Inc., , CL, Canceled, 09/15/2001]',
#  '[CMA306, WPSM292, Texas #20 Rural Cellular, Inc., 0002841906, CL, Expired, 12/17/2001]',
#  '[CMA306, WPTE522, Florida RSA #8, Inc., 0002210086, CL, Expired, 03/12/2002]',
#  '[CMA306, WPTG983, USCOC of Tallahassee, Inc., , CL, Canceled, 03/15/2002]',
#  '[CMA306, WPTG984, USCOC of Tallahassee, Inc., , CL, Canceled, 03/15/2002]',
#  '[CMA306, WPTX508, TEXAS #20 RURAL CELLULAR, INC., 0002841906, CL, Canceled, 06/14/2002]',
#  '[CMA306, WPUN203, USCOC of Tallahassee, Inc., , CL, Canceled, 03/09/2003]',
#  '[CMA306, WPUN211, USCOC of Tallahassee, Inc., , CL, Canceled, 03/09/2003]',
#  '[CMA306, WPUP627, Florida RSA #8, Inc., 0002210086, CL, Canceled, 06/14/2002]',
#  '[CMA306, WPUP631, Florida RSA #8, Inc., 0002210086, CL, Canceled, 06/14/2002]',
#  '[CMA306, WPVA875, FLORIDA RSA #8, INC., 0002210086, CL, Canceled, 12/12/2002]',
#  '[CMA306, WPVA876, FLORIDA RSA #8, INC., 0002210086, CL, Canceled, 12/12/2002]',
#  '[CMA306, WPWV330, RigNet Satcom, Inc, 0015217680, WZ, Active, 06/13/2019]',
#  '[CMA306, WQGD708, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 12/18/2021]',
#  '[CMA306, WQIZ526, Chevron USA Inc., 0003194933, WY, Active, 06/13/2019]',
#  '[CMA306, WQWD617, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 09/24/2028]',
#  '[CMA306, WQWD618, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 09/24/2028]',
#  '',
#  '[CMA307, KNKN903, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 10/01/2021]',
#  '[CMA307, KNKN904, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 10/01/2021]',
#  '[CMA307, KNKP866, Cellco Partnership dba Verizon Wireless, 0003290673, CL, Canceled, 10/01/2005]',
#  '[CMA307, KNKQ223, GTE MOBILNET OF FLORENCE, ALABAMA INC., 0001573518, CL, Canceled, 10/01/2001]',
#  '[CMA307, KNKQ247, ALABAMA 1 - FRANKLIN RSA PARTNERSHIP, 0001753367, CL, Canceled, 10/01/2001]',
#  '[CMA307, KNKQ276, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2020]',
#  '[CMA307, KNKQ359, NORTH ALABAMA CELLULAR, LLC., , CL, Expired, 10/01/2001]',
#  '[CMA307, KNKQ369, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2023]',
#  '[CMA307, KNKR324, Cellco Partnership, 0003290673, CL, Active, 06/03/2027]',
#  '[CMA307, L000010903, New Cingular Wireless PCS, LLC, 0003291192, WZ, Canceled, 02/20/2014]',
#  '[CMA307, WPZL286, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA307, WQGD709, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA307, WQJU574, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '',
#  '[CMA311, KNKN685, NEW CINGULAR WIRELESS PCS, LLC, 0003291192, CL, Active, 10/01/2020]',
#  '[CMA311, KNKN686, ALLTEL Corporation, 0002942159, CL, Active, 10/01/2021]',
#  '[CMA311, KNKN687, ALLTEL Corporation, 0002942159, CL, Active, 10/01/2020]',
#  '[CMA311, KNKP973, Price Communications Wireless II Inc, 0003474152, CL, Expired, 10/01/2003]',
#  '[CMA311, KNKQ224, GTE MOBILNET OF ALABAMA INCORPORATED, 0001574649, CL, Canceled, 10/01/2001]',
#  '[CMA311, KNKQ227, GTE WIRELESS OF THE SOUTH INCORPORATED, 0001843887, CL, Canceled, 10/01/2001]',
#  '[CMA311, KNKQ444, Rural Cellular Corporation, 0003715919, CL, Active, 11/01/2027]',
#  '[CMA311, L000007319, Cellco Partnership, 0003290673, CL, Active, 11/01/2027]',
#  '[CMA311, L000010904, New Cingular Wireless PCS, LLC, 0003291192, WZ, Canceled, 02/20/2014]',
#  '[CMA311, L000011534, Cellco Partnership, 0003290673, AW, Canceled, 11/12/2014]',
#  '[CMA311, WPZL287, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA311, WQGD518, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA311, WQIZ487, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '[CMA311, WQNZ381, Alltel Communications, LLC, 0018437624, CL, Canceled, 10/15/2011]',
#  '',
#  '[CMA313, KNKN725, New Cingular Wireless PCS, LLC, 0003291192, CL, Active, 10/01/2020]',
#  '[CMA313, KNKQ208, PALMER CELLULAR PARTNERSHIP, , CL, Expired, 10/01/2000]',
#  '[CMA313, KNKQ378, Rural Cellular Corporation, 0003715919, CL, Active, 10/01/2023]',
#  '[CMA313, L000004263, W. Stephen Cannon, Management Trustee, 0017119025, CL, Expired, 12/30/2009]',
#  '[CMA313, L000006260, W. Stephen Cannon, Management Trustee, 0017119025, CL, Canceled, 10/01/2010]',
#  '[CMA313, L000007543, AT&T MOBILITY II LLC, 0016982233, CL, Canceled, 10/01/2010]',
#  '[CMA313, L000010909, New Cingular Wireless PCS, LLC, 0003291192, WZ, Canceled, 02/20/2014]',
#  '[CMA313, WQBQ616, New Cingular Wireless PCS, LLC, 0003291192, WZ, Active, 06/13/2019]',
#  '[CMA313, WQGB236, New Cingular Wireless PCS, LLC, 0003291192, AW, Active, 11/29/2021]',
#  '[CMA313, WQIZ488, New Cingular Wireless PCS, LLC, 0003291192, WY, Active, 06/13/2019]',
#  '',
#  '[CMA315, KNKN204, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/01/2024]',
#  '[CMA315, KNKN407, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2020]',
#  '[CMA315, KNKQ408, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, CL, Active, 10/01/2020]',
#  '[CMA315, KNKR318, OTZ Telecommunications, LLC, 0004334538, CL, Active, 01/22/2028]',
#  '[CMA315, L000003693, AlasConnect Inc., 0000021188, WZ, Canceled, 02/17/2019]',
#  '[CMA315, L000003772, University of Cincinnati Geography Dept., 0017706060, WZ, Canceled, 03/10/2014]',
#  '[CMA315, L000005684, GCI Communication Corp., 0001568880, CL, Active, 06/30/2019]',
#  '[CMA315, L000005685, GCI Communication Corp., 0001568880, CL, Active, 06/30/2019]',
#  '[CMA315, L000005689, GCI Communication Corp., 0001568880, CL, Active, 07/01/2019]',
#  '[CMA315, L000005690, GCI Communication Corp., 0001568880, CL, Active, 07/08/2019]',
#  '[CMA315, L000013449, AlasConnect Inc, 0000021188, WY, Expired, 01/01/2015]',
#  '[CMA315, L000019087, OTZ Telecommunications, LLC, 0004334538, WZ, Expired, 03/25/2017]',
#  '[CMA315, L000020290, OTZ Telecommunications, LLC, 0004334538, WZ, Active, 06/13/2019]',
#  '[CMA315, L000023099, AT&T Mobility Spectrum LLC, 0014980726, WZ, Canceled, 12/10/2017]',
#  '[CMA315, L000023100, AT&T Mobility Spectrum, LLC, 0014980726, WZ, Expired, 12/10/2016]',
#  '[CMA315, L000023101, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA315, L000031628, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, WY, Canceled, 02/19/2019]',
#  '[CMA315, L000031689, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, WY, Active, 06/13/2019]',
#  '[CMA315, WPOI466, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 03/01/2029]',
#  '[CMA315, WPOJ688, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 06/30/2019]',
#  '[CMA315, WPOJ693, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 06/30/2019]',
#  '[CMA315, WPOJ694, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 06/30/2019]',
#  '[CMA315, WPOJ853, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 07/01/2019]',
#  '[CMA315, WPOJ865, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 07/08/2019]',
#  '[CMA315, WPOJ867, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 07/08/2019]',
#  '[CMA315, WPOL591, Pacific Telecom Cellular of Alaska RSA #1, Inc., 0001568773, CL, Expired, 06/20/2000]',
#  '[CMA315, WPWU902, ARCTIC SLOPE TELEPHONE ASSOCIATION COOPERATIVE, INC., 0001570936, WZ, Active, 06/13/2019]',
#  '[CMA315, WQBB914, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, CL, Expired, 03/15/2005]',
#  '[CMA315, WQIA880, Space Data Spectrum Holdings, LLC, 0004983664, AW, Active, 12/12/2022]',
#  '[CMA315, WQIQ308, TelAlaska Cellular, Inc., 0003740768, CL, Active, 04/11/2028]',
#  '[CMA315, WQIZ358, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA315, WQJL936, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/29/2028]',
#  '[CMA315, WQKK274, ASTAC Wireless LLC, 0016876641, CL, Expired, 08/18/2009]',
#  '[CMA315, WQKY736, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/28/2019]',
#  '[CMA315, WQKY737, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/28/2019]',
#  '[CMA315, WQMJ965, ASTAC Wireless LLC, 0016876641, CL, Expired, 10/29/2010]',
#  '[CMA315, WQUW883, The Alaska Wireless Network, LLC, 0021818133, CL, Expired, 01/03/2015]',
#  '[CMA315, WQWQ807, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '[CMA315, WRBZ793, The Alaska Wireless Network, LLC, 0021818133, CL, Canceled, 10/02/2018]',
#  '',
#  '[CMA316, KNKN287, GTE WIRELESS OF THE SOUTH INC., , CL, Expired, 10/01/1999]',
#  '[CMA316, KNKQ204, AT&T WIRELESS SERVICES OF ALASKA, INC., 0004122032, CL, Canceled, 10/01/2000]',
#  '[CMA316, KNKQ331, BRISTOL BAY CELLULAR PARTNERSHIP, 0001568898, CL, Active, 10/01/2019]',
#  '[CMA316, KNKQ340, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/01/2019]',
#  '[CMA316, KNKQ398, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/01/2019]',
#  '[CMA316, KNKQ401, Copper Valley Wireless, LLC, 0022505283, CL, Active, 10/01/2019]',
#  '[CMA316, KNKQ402, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2024]',
#  '[CMA316, KNKR274, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 07/11/2026]',
#  '[CMA316, KNKR275, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/01/2025]',
#  '[CMA316, KNKR287, ACS Wireless License Sub, Inc., 0004525325, CL, Terminated, ]',
#  '[CMA316, L000002387, Strata8 Networks, Inc., 0016161366, CL, Expired, 09/19/2008]',
#  '[CMA316, L000005683, GCI Communication Corp., 0001568880, CL, Active, 10/01/2015]',
#  '[CMA316, L000005686, GCI Communication Corp., 0001568880, CL, Active, 06/30/2019]',
#  '[CMA316, L000005687, GCI Communication Corp., 0001568880, CL, Active, 06/30/2019]',
#  '[CMA316, L000005688, GCI Communication Corp., 0001568880, CL, Active, 06/30/2019]',
#  '[CMA316, L000015992, Cordova Wireless Communications, LLC, 0004333589, WY, Canceled, 06/13/2019]',
#  '[CMA316, L000019234, Cellco Partnership, 0003290673, AW, Canceled, 02/11/2017]',
#  '[CMA316, L000031627, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, WZ, Canceled, 02/19/2019]',
#  '[CMA316, L000031629, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, WY, Canceled, 02/19/2019]',
#  '[CMA316, L000031688, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, WZ, Active, 06/13/2019]',
#  '[CMA316, L000031690, Arctic Slope Telephone Association Cooperative, Inc., 0001570936, WY, Active, 06/13/2019]',
#  '[CMA316, L000033667, Cordova Wireless Communications, LLC, 0004333589, WY, Active, 06/13/2019]',
#  '[CMA316, WPOJ849, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 06/30/2019]',
#  '[CMA316, WPOJ850, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 06/30/2019]',
#  '[CMA316, WPOJ851, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 06/30/2019]',
#  '[CMA316, WPOL233, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/21/2019]',
#  '[CMA316, WPOL234, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/22/2019]',
#  '[CMA316, WPOL372, Cordova Wireless Communications, LLC, 0004333589, CL, Active, 10/01/2024]',
#  '[CMA316, WPON879, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 04/25/2020]',
#  '[CMA316, WPRZ809, Matanuska Telephone Association, 0001573427, CL, Canceled, 03/19/2021]',
#  '[CMA316, WPWF379, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 11/04/2022]',
#  '[CMA316, WPYE240, Cordova Wireless Communications, LLC, 0004333589, CL, Active, 07/25/2023]',
#  '[CMA316, WPYZ889, AT&T Mobility Spectrum LLC, 0014980726, WZ, Active, 06/13/2019]',
#  '[CMA316, WQCL946, ALASKA WIRELESS COMMUNICATIONS, LLC, 0007565427, CL, Expired, 10/02/2005]',
#  '[CMA316, WQDL859, Jasper Technologies, Inc., 0013670583, CL, Canceled, 04/25/2020]',
#  '[CMA316, WQGD637, Cellco Partnership, 0003290673, AW, Active, 12/18/2021]',
#  '[CMA316, WQIQ306, TelAlaska Cellular, Inc., 0003740768, CL, Active, 04/11/2028]',
#  '[CMA316, WQIQ784, Windy City Cellular LLC, 0017413329, CL, Active, 04/16/2028]',
#  '[CMA316, WQIZ597, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA316, WQLC364, Copper Valley Wireless, Inc., 0001568302, CL, Expired, 10/04/2011]',
#  '[CMA316, WQLF434, TelAlaska Cellular, Inc., 0003740768, CL, Active, 10/01/2019]',
#  '[CMA316, WQWQ808, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '[CMA316, WQWV601, The Alaska Wireless Newtork, LLC, 0021818133, CL, Expired, 02/02/2016]',
#  '[CMA316, WRBT330, OptimEra Inc., 0021762067, CL, Active, 06/12/2028]',
#  '',
#  '[CMA317, KNKN261, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 10/01/2020]',
#  '[CMA317, KNKQ316, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2021]',
#  '[CMA317, KNKQ435, PACIFIC TELECOM CELLULAR OF ALASKA, , CL, Terminated, ]',
#  '[CMA317, KNNA200, ALT, PAUL/CHI TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, KNNA201, BACH, PHILLIP/ZETA TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, KNNA202, BERGER, VINCENT/ETA TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, KNNA203, BONDS, FAY / EPSILON TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, KNNA204, BRISCOE, BRIAN / DELTA TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, KNNA205, BROWN, GLORIA / BETA TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, KNNA206, BRUCE, TOBY / ALPHA TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, KNNA207, NELSON, GLEN / THETA TRUST PARTNERSHIP, , CL, Canceled, ]',
#  '[CMA317, L000002684, Kwaan Wireless, Inc., 0017357146, WZ, Terminated, 01/01/2015]',
#  '[CMA317, L000031728, City of Ketchikan dba Ketchikan Public Utilities, 0004325148, AW, Active, 11/29/2021]',
#  '[CMA317, L000033668, Cordova Wireless Communications, LLC, 0004333589, WY, Active, 06/13/2019]',
#  '[CMA317, WPWU972, City of Ketchikan dba Ketchikan Public Utilities, 0004325148, WZ, Active, 06/13/2019]',
#  '[CMA317, WQGB262, City of Ketchikan d.b.a. Ketchikan Public Utilities, 0004325148, AW, Active, 11/29/2021]',
#  '[CMA317, WQIZ598, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]',
#  '[CMA317, WQQZ490, The Alaska Wireless Network, LLC, 0021818133, CL, Active, 03/29/2023]',
#  '[CMA317, WQSL580, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]',
#  '[CMA317, WQVA555, The Alaska Wireless Network, LLC, 0021818133, CL, Expired, 02/06/2015]',
#  '[CMA317, WQWQ809, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]',
#  '']

# %%
row = table_str[0]
re_row = re.search('(?:\[)(.+)(?:\])', table_str[0])
re_row[1].split(',')
# Out:
# ['CMA002',
#  ' KNKA209',
#  ' Los Angeles SMSA Limited Partnership',
#  ' 0002963817',
#  ' CL',
#  ' Active',
#  ' 10/01/2024']

# %%
fixed = []

for row in table_str:
    print(row)
    re_row = re.search('(?:\[)(.+)(?:\])', row)
    fixed += re_row[1].split(',')
# Out:
# [CMA002, KNKA209, Los Angeles SMSA Limited Partnership, 0002963817, CL, Active, 10/01/2024]
# [CMA002, KNKA351, AT&T Mobility Spectrum LLC, 0014980726, CL, Active, 10/01/2027]
# [CMA002, KNKR294, FOLDEN, GENE A, , CL, Terminated, ]
# [CMA002, KNKR313, LOS ANGELES SMSA LIMITED PARTNERSHIP, 0002963817, CL, Canceled, 09/24/2007]
# [CMA002, L000009285, AirTouch Cellular, 0006146468, WY, Canceled, 06/13/2019]
# [CMA002, L000010911, Cellco Partnership, 0003290673, AW, Canceled, 01/25/2014]
# [CMA002, L000010913, New Cingular Wireless PCS, LLC, 0003291192, WY, Canceled, 01/25/2014]
# [CMA002, L000015067, Screened Images, Inc., 0021044003, CL, Active, 10/01/2027]
# [CMA002, L000023743, Screened Images, Inc., 0021044003, AW, Active, 11/29/2021]
# [CMA002, WPOI449, Los Angeles SMSA Limited Partnership-AirTouch Cellular, 0002963817, CL, Canceled, 02/18/2009]
# [CMA002, WPWU990, AT&T Mobility LLC, 0014980726, WZ, Active, 06/13/2019]
# [CMA002, WQGA742, AT&T Mobility Spectrum LLC, 0014980726, AW, Active, 11/29/2021]
# [CMA002, WQJQ721, AT&T Mobility Spectrum LLC, 0014980726, WY, Active, 06/13/2019]
# [CMA002, WQSH611, Cellco Partnership, 0003290673, AW, Active, 11/29/2021]
# [CMA002, WQWQ746, Northstar Wireless, LLC, 0023917453, AT, Active, 10/27/2027]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-194-60fc1db23d93> in <module>()
#       8     print(row)
#       9     re_row = re.search('(?:\[)(.+)(?:\])', row)
# ---> 10     fixed += re_row[1].split(',')
#
# TypeError: 'NoneType' object is not subscriptable

# %%
for row in table_str:
    lst_strings = re.findall('(?:\[)(.+)(?:\])',row)
    print(lst_strings)
    fixed.append(re.search('(?:\[)(.+)(?:\]\\n)', row))

pd.DataFrame(fixed)
# Out:
# ['CMA002',
#  ' KNKA209',
#  ' Los Angeles SMSA Limited Partnership',
#  ' 0002963817',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA002',
#  ' KNKA351',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' CL',
#  ' Active',
#  ' 10/01/2027',
#  '',
#  'CMA002',
#  ' KNKR294',
#  ' FOLDEN',
#  ' GENE A',
#  ' ',
#  ' CL',
#  ' Terminated',
#  ' ',
#  '',
#  'CMA002',
#  ' KNKR313',
#  ' LOS ANGELES SMSA LIMITED PARTNERSHIP',
#  ' 0002963817',
#  ' CL',
#  ' Canceled',
#  ' 09/24/2007',
#  '',
#  'CMA002',
#  ' L000009285',
#  ' AirTouch Cellular',
#  ' 0006146468',
#  ' WY',
#  ' Canceled',
#  ' 06/13/2019',
#  '',
#  'CMA002',
#  ' L000010911',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Canceled',
#  ' 01/25/2014',
#  '',
#  'CMA002',
#  ' L000010913',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WY',
#  ' Canceled',
#  ' 01/25/2014',
#  '',
#  'CMA002',
#  ' L000015067',
#  ' Screened Images',
#  ' Inc.',
#  ' 0021044003',
#  ' CL',
#  ' Active',
#  ' 10/01/2027',
#  '',
#  'CMA002',
#  ' L000023743',
#  ' Screened Images',
#  ' Inc.',
#  ' 0021044003',
#  ' AW',
#  ' Active',
#  ' 11/29/2021',
#  '',
#  'CMA002',
#  ' WPOI449',
#  ' Los Angeles SMSA Limited Partnership-AirTouch Cellular',
#  ' 0002963817',
#  ' CL',
#  ' Canceled',
#  ' 02/18/2009',
#  '',
#  'CMA002',
#  ' WPWU990',
#  ' AT&T Mobility LLC',
#  ' 0014980726',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA002',
#  ' WQGA742',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' AW',
#  ' Active',
#  ' 11/29/2021',
#  '',
#  'CMA002',
#  ' WQJQ721',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA002',
#  ' WQSH611',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Active',
#  ' 11/29/2021',
#  '',
#  'CMA002',
#  ' WQWQ746',
#  ' Northstar Wireless',
#  ' LLC',
#  ' 0023917453',
#  ' AT',
#  ' Active',
#  ' 10/27/2027',
#  '',
#  '',
#  'CMA014',
#  ' KNKA232',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA014',
#  ' KNKA242',
#  ' NEW CINGULAR WIRELESS PCS',
#  ' LLC',
#  ' 0003291192',
#  ' CL',
#  ' Active',
#  ' 10/01/2023',
#  '',
#  'CMA014',
#  ' L000010153',
#  ' Tecore Government Services',
#  ' LLC',
#  ' 0019878172',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA014',
#  ' L000011612',
#  ' Tecore Government Services',
#  ' LLC',
#  ' 0019878172',
#  ' CL',
#  ' Expired',
#  ' 10/01/2014',
#  '',
#  'CMA014',
#  ' L000015304',
#  ' Tecore Government Services',
#  ' LLC',
#  ' 0019878172',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA014',
#  ' L000017021',
#  ' Tecore Government Services',
#  ' LLC',
#  ' 0019878172',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA014',
#  ' L000017022',
#  ' Tecore Government Services',
#  ' LLC',
#  ' 0019878172',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA014',
#  ' L000017299',
#  ' Tecore Government Services',
#  ' LLC',
#  ' 0019878172',
#  ' CL',
#  ' Active',
#  ' 10/01/2023',
#  '',
#  'CMA014',
#  ' WPWU996',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA014',
#  ' WQGD674',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA014',
#  ' WQJU434',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA014',
#  ' WQWQ991',
#  ' SNR Wireless LicenseCo',
#  ' LLC',
#  ' 0023907074',
#  ' AT',
#  ' Active',
#  ' 10/27/2027',
#  '',
#  '',
#  'CMA015',
#  ' KNKA219',
#  ' Verizon Wireless (VAW) LLC',
#  ' 0003800307',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA015',
#  ' KNKA247',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA015',
#  ' KNKR295',
#  ' DELTA CELLULAR PARTNERS I',
#  ' ',
#  ' CL',
#  ' Terminated',
#  ' ',
#  '',
#  'CMA015',
#  ' KNKR320',
#  ' ALLTEL Corporation',
#  ' 0002942159',
#  ' CL',
#  ' Active',
#  ' 04/02/2028',
#  '',
#  'CMA015',
#  ' L000007696',
#  ' Game Day Entertainment LLC',
#  ' 0019860683',
#  ' WZ',
#  ' Expired',
#  ' 02/14/2011',
#  '',
#  'CMA015',
#  ' WPOI246',
#  ' McElroy Electronics Corporation',
#  ' 0003623725',
#  ' CL',
#  ' Terminated',
#  ' 01/19/2009',
#  '',
#  'CMA015',
#  ' WPOI462',
#  ' McElroy Electronics Corporation',
#  ' 0003623725',
#  ' CL',
#  ' Canceled',
#  ' 02/25/2009',
#  '',
#  'CMA015',
#  ' WPWV436',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA015',
#  ' WQGD675',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA015',
#  ' WQJU435',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA015',
#  ' WQWQ992',
#  ' SNR Wireless LicenseCo',
#  ' LLC',
#  ' 0023907074',
#  ' AT',
#  ' Active',
#  ' 10/27/2027',
#  '',
#  '',
#  'CMA024',
#  ' KNKA223',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' CL',
#  ' Active',
#  ' 10/01/2023',
#  '',
#  'CMA024',
#  ' KNKA337',
#  ' Verizon Wireless (VAW) LLC',
#  ' 0003800307',
#  ' CL',
#  ' Active',
#  ' 02/09/2026',
#  '',
#  'CMA024',
#  ' KNKR207',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' CL',
#  ' Active',
#  ' 10/01/2025',
#  '',
#  'CMA024',
#  ' WPOI251',
#  ' Dobson Cellular of Kansas/Missouri Inc  CELLULARONE',
#  ' 0001697077',
#  ' CL',
#  ' Canceled',
#  ' 01/25/2009',
#  '',
#  'CMA024',
#  ' WPOI261',
#  ' AWZ Cellular Corporation',
#  ' 0002148682',
#  ' CL',
#  ' Canceled',
#  ' 01/25/2009',
#  '',
#  'CMA024',
#  ' WPOI418',
#  ' Missouri RSA No 7 Limited Partnership Dba/Mid Missouri Cellular',
#  ' 0002535276',
#  ' CL',
#  ' Canceled',
#  ' 02/04/2009',
#  '',
#  'CMA024',
#  ' WPWV203',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA024',
#  ' WPZP958',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' CL',
#  ' Active',
#  ' 10/01/2025',
#  '',
#  'CMA024',
#  ' WQGD677',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA024',
#  ' WQJU443',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA024',
#  ' WQWQ995',
#  ' SNR Wireless LicenseCo',
#  ' LLC',
#  ' 0023907074',
#  ' AT',
#  ' Active',
#  ' 10/27/2027',
#  '',
#  '',
#  'CMA026',
#  ' KNKA205',
#  ' Verizon Wireless (VAW) LLC',
#  ' 0003800307',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA026',
#  ' KNKA303',
#  ' ALLTEL Corporation',
#  ' 0002942159',
#  ' CL',
#  ' Active',
#  ' 02/09/2026',
#  '',
#  'CMA026',
#  ' KNKR208',
#  ' Commnet of Arizona',
#  ' LLC',
#  ' 0009291220',
#  ' CL',
#  ' Active',
#  ' 10/01/2025',
#  '',
#  'CMA026',
#  ' L000005002',
#  ' James H. Wanserski',
#  ' Hold Separate Trustee',
#  ' 0018360701',
#  ' CL',
#  ' Canceled',
#  ' 12/30/2009',
#  '',
#  'CMA026',
#  ' L000018826',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' AW',
#  ' Canceled',
#  ' 09/15/2016',
#  '',
#  'CMA026',
#  ' L000018836',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' AW',
#  ' Canceled',
#  ' 09/15/2016',
#  '',
#  'CMA026',
#  ' WPOI420',
#  ' Southwestco Wireless Limited Partnership',
#  ' 0003290525',
#  ' CL',
#  ' Canceled',
#  ' 02/04/2009',
#  '',
#  'CMA026',
#  ' WPOK974',
#  ' Southwestco Wireless Limited Partnership',
#  ' 0003290525',
#  ' CL',
#  ' Canceled',
#  ' 10/15/2009',
#  '',
#  'CMA026',
#  ' WPOK988',
#  ' Gila River Cellular General Partnership',
#  ' 0001607183',
#  ' CL',
#  ' Canceled',
#  ' 10/01/2005',
#  '',
#  'CMA026',
#  ' WPWV204',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA026',
#  ' WQGA745',
#  ' T-Mobile License LLC',
#  ' 0001565449',
#  ' AW',
#  ' Canceled',
#  ' 11/29/2021',
#  '',
#  'CMA026',
#  ' WQJU445',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA026',
#  ' WQVP373',
#  ' T-Mobile License LLC',
#  ' 0001565449',
#  ' AT',
#  ' Active',
#  ' 04/08/2027',
#  '',
#  'CMA026',
#  ' WQXK658',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' AW',
#  ' Active',
#  ' 11/29/2021',
#  '',
#  'CMA026',
#  ' WQXQ398',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' AW',
#  ' Active',
#  ' 11/29/2021',
#  '',
#  '',
#  'CMA028',
#  ' KNKA208',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' CL',
#  ' Active',
#  ' 10/01/2023',
#  '',
#  'CMA028',
#  ' KNKA216',
#  ' GTE MOBILNET OF INDIANA LIMITED PARTNERSHIP',
#  ' 0003579364',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA028',
#  ' L000020043',
#  ' Shawntech Communications',
#  ' Inc',
#  ' 0018990028',
#  ' WZ',
#  ' Canceled',
#  ' 12/31/2016',
#  '',
#  'CMA028',
#  ' L000020052',
#  ' Shawntech Communications',
#  ' Inc',
#  ' 0018990028',
#  ' AW',
#  ' Canceled',
#  ' 12/31/2016',
#  '',
#  'CMA028',
#  ' L000020057',
#  ' Shawntech Communications',
#  ' Inc',
#  ' 0018990028',
#  ' WY',
#  ' Canceled',
#  ' 12/31/2016',
#  '',
#  'CMA028',
#  ' L000024819',
#  ' Shawntech Communications',
#  ' Inc',
#  ' 0018990028',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA028',
#  ' L000024830',
#  ' Shawntech Communications',
#  ' Inc',
#  ' 0018990028',
#  ' AW',
#  ' Active',
#  ' 07/31/2020',
#  '',
#  'CMA028',
#  ' L000024838',
#  ' Shawntech Communications',
#  ' Inc',
#  ' 0018990028',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA028',
#  ' L000024843',
#  ' Shawntech Communications',
#  ' Inc',
#  ' 0018990028',
#  ' AT',
#  ' Active',
#  ' 07/31/2020',
#  '',
#  'CMA028',
#  ' WPWV205',
#  ' AT&T Mobility LLC',
#  ' 0014980726',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA028',
#  ' WQGD481',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA028',
#  ' WQJU447',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA028',
#  ' WQVN882',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' AT',
#  ' Active',
#  ' 04/08/2027',
#  '',
#  '',
#  'CMA029',
#  ' KNKA224',
#  ' NEW CINGULAR WIRELESS PCS',
#  ' LLC',
#  ' 0003291192',
#  ' CL',
#  ' Active',
#  ' 10/01/2023',
#  '',
#  'CMA029',
#  ' KNKA352',
#  ' ALLTEL Corporation',
#  ' 0002942159',
#  ' CL',
#  ' Active',
#  ' 05/15/2025',
#  '',
#  'CMA029',
#  ' KNKR209',
#  ' ALLTEL Corporation',
#  ' 0002942159',
#  ' CL',
#  ' Active',
#  ' 10/01/2025',
#  '',
#  'CMA029',
#  ' L000009685',
#  ' T-Mobile License LLC',
#  ' 0001565449',
#  ' AW',
#  ' Expired',
#  ' 05/15/2012',
#  '',
#  'CMA029',
#  ' L000010530',
#  ' T-Mobile License LLC',
#  ' 0001565449',
#  ' AW',
#  ' Expired',
#  ' 02/13/2013',
#  '',
#  'CMA029',
#  ' L000022013',
#  ' CellBlox Acquisitions',
#  ' LLC',
#  ' 0024202053',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA029',
#  ' L000022014',
#  ' CellBlox Acquisitions',
#  ' LLC',
#  ' 0024202053',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA029',
#  ' L000022015',
#  ' CellBlox Acquisitions',
#  ' LLC',
#  ' 0024202053',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA029',
#  ' L000022977',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Canceled',
#  ' 01/01/2018',
#  '',
#  'CMA029',
#  ' L000030956',
#  ' CellBlox Acquisitions',
#  ' LLC',
#  ' 0024202053',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA029',
#  ' WPWV206',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA029',
#  ' WQGD678',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA029',
#  ' WQJU448',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA029',
#  ' WQWQ997',
#  ' SNR Wireless LicenseCo',
#  ' LLC',
#  ' 0023907074',
#  ' AT',
#  ' Active',
#  ' 10/27/2027',
#  '',
#  '',
#  'CMA039',
#  ' KNKA259',
#  ' Verizon Wireless (VAW) LLC',
#  ' 0003800307',
#  ' CL',
#  ' Active',
#  ' 05/15/2025',
#  '',
#  'CMA039',
#  ' KNKA376',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' CL',
#  ' Active',
#  ' 10/01/2026',
#  '',
#  'CMA039',
#  ' KNKR211',
#  ' Verizon Wireless (VAW) LLC',
#  ' 0003800307',
#  ' CL',
#  ' Active',
#  ' 10/01/2025',
#  '',
#  'CMA039',
#  ' KNKR281',
#  ' WYNDOM CELLULAR CORPORATION',
#  ' ',
#  ' CL',
#  ' Terminated',
#  ' ',
#  '',
#  'CMA039',
#  ' L000009978',
#  ' T-Mobile License LLC',
#  ' 0001565449',
#  ' AW',
#  ' Canceled',
#  ' 02/28/2013',
#  '',
#  'CMA039',
#  ' WPWV488',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA039',
#  ' WQGB278',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Active',
#  ' 11/29/2021',
#  '',
#  'CMA039',
#  ' WQJU456',
#  ' AT&T Mobility Spectrum LLC',
#  ' 0014980726',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA039',
#  ' WQTK392',
#  ' Commnet of Nevada',
#  ' LLC',
#  ' 0018122879',
#  ' CL',
#  ' Terminated',
#  ' 02/21/2024',
#  '',
#  'CMA039',
#  ' WQVP374',
#  ' T-Mobile License LLC',
#  ' 0001565449',
#  ' AT',
#  ' Active',
#  ' 04/08/2027',
#  '',
#  '',
#  'CMA041',
#  ' KNKA262',
#  ' NEW CINGULAR WIRELESS PCS',
#  ' LLC',
#  ' 0003291192',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA041',
#  ' KNKA343',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' CL',
#  ' Active',
#  ' 11/29/2026',
#  '',
#  'CMA041',
#  ' KNKR270',
#  ' LONESOME DOVE CELLULAR',
#  ' LTD.',
#  ' ',
#  ' CL',
#  ' Canceled',
#  ' 10/01/2005',
#  '',
#  'CMA041',
#  ' L000009671',
#  ' T-Mobile License LLC',
#  ' 0001565449',
#  ' AW',
#  ' Canceled',
#  ' 04/14/2013',
#  '',
#  'CMA041',
#  ' L000010899',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WZ',
#  ' Canceled',
#  ' 02/20/2014',
#  '',
#  'CMA041',
#  ' L000011548',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Canceled',
#  ' 11/12/2014',
#  '',
#  'CMA041',
#  ' WPZL282',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA041',
#  ' WQGD680',
#  ' Cellco Partnership',
#  ' 0003290673',
#  ' AW',
#  ' Active',
#  ' 12/18/2021',
#  '',
#  'CMA041',
#  ' WQJU458',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WY',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA041',
#  ' WQWQ757',
#  ' Northstar Wireless',
#  ' LLC',
#  ' 0023917453',
#  ' AT',
#  ' Active',
#  ' 10/27/2027',
#  '',
#  '',
#  'CMA045',
#  ' KNKA296',
#  ' OKLAHOMA CITY SMSA LIMITED PARTNERSHIP',
#  ' 0001658392',
#  ' CL',
#  ' Active',
#  ' 10/01/2024',
#  '',
#  'CMA045',
#  ' KNKA298',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' CL',
#  ' Active',
#  ' 05/15/2025',
#  '',
#  'CMA045',
#  ' KNKA369',
#  ' ALLTEL Corporation',
#  ' 0002942159',
#  ' CL',
#  ' Active',
#  ' 10/01/2025',
#  '',
#  'CMA045',
#  ' KNKR212',
#  ' NEW CINGULAR WIRELESS PCS',
#  ' LLC',
#  ' 0003291192',
#  ' CL',
#  ' Active',
#  ' 04/02/2026',
#  '',
#  'CMA045',
#  ' L000010919',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WY',
#  ' Canceled',
#  ' 01/25/2014',
#  '',
#  'CMA045',
#  ' WPWV214',
#  ' New Cingular Wireless PCS',
#  ' LLC',
#  ' 0003291192',
#  ' WZ',
#  ' Active',
#  ' 06/13/2019',
#  '',
#  'CMA045',
#  ' WQEG235',
#  ...]
