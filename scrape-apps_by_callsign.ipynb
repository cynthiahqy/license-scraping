# %% [markdown]
# # FCC Application Scraping

# %% [markdown]
# ## Set up selenium webdriver with Firefox
# * Download Firefox driver [geckodriver](https://github.com/mozilla/geckodriver/releases) for selenium
# * Move the driver executable into the same directory as this notebook (or update the path to the executable in `scrape_table_for_call_sign`)
# * `pip install selenium`

# %%
from bs4 import BeautifulSoup
import time
import random
import csv

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options  
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException

# %%
import os
import pandas as pd

# %% [markdown]
# ## Define functions for scraping table for an individual call sign

# %%
def element_exists(driver, xpath):
    """
    Helper function that checks if the element at the given xpath exists on
    driver's current page. This is used to check if there is a "Next" button
    -- to scrape through multiple pages of the FCC's paginated tables.
    """
    try:
        driver.find_element_by_xpath(xpath)
    except NoSuchElementException:
        return False
    return True

# %%
def extract_callsign(innerHTML):
    '''
    Helper function that extracts the callsign from Application search results page.
    This is used to append the CALLSIGN to each row when scraping table data
    '''
    soup = BeautifulSoup(innerHTML, "lxml")
    
    # tag attributes for element containing text "Call Sign = " 
    tag_attrs = {"class":"cell-pri-light", "valign":"bottom", "align":"left"}
    
    # extract callsign as text
    callsign = (
        soup.find_all(attrs=tag_attrs, limit=1)[0]
        .find_all("b")[0]
        .get_text()
    )
    
    return callsign

# %%
def count_results(innerHTML):
    '''
    Helper function that extracts the total number of results across all pages.
    This is used to check the scraped table data has the expected number of rows.
    '''
    
    soup = BeautifulSoup(innerHTML, "lxml")
    
    # tag attributes for element containing text "Matches 1-47 (of 47)"
    tag_attrs = {"class":"cell-pri-dark", "width":"35%", "valign":"middle", "align":"left"}

    # extract results count from inside "(of 47)" as integer 47
    count = int(soup.find_all(attrs=tag_attrs, limit=1)[0]
                .find_all("b")[1]
                .get_text()
               )
    
    return count

# %%
def scrape_table_page(innerHTML):
    """
    Extracts the following details from a call sign table page:
        * File Number
        * Call Sign/Lease ID
        * Applicant Name
        * FRN
        * Purpose - split into Purpose_Main and Purpose_Note
        * Radio
        * Service
        * Receipt
        * Date
        * Status
    Returns as a list of lists.
    """
    
    # Extract search data from innerHTML soup
    soup = BeautifulSoup(innerHTML, "lxml")

    CALLSIGN = extract_callsign(innerHTML)
    table_page = soup.find("table", {"summary": "Application search results"})
    
    # Extract search results as list of rows
    rows = table_page.find_all("tr")[1:-1] # note: skip header and pagination rows
    
    # Extract results by row into table, attaching callsign number
    table_data = []
    
    for row in rows:  
        
        row_data = [CALLSIGN, ]
        cols = row.find_all("td")
        
        # extract values from each cell in row
        for i in range(1, len(cols)): # note: skip the first (index) cell
            
            # extract cell data, trim leading/trailing whitespace
            cell_data = cols[i].get_text().strip()
            
            # fifth-index cells "Purpose" has to get split into two cols
            if i == 5:
                
                purpose = cell_data.split("\n")
                purpose_main = purpose[0].strip()
                purpose_note = ""
                
                # sometimes the "Purpose" column has an optional note
                if len(purpose) >= 2:
                    purpose_note = purpose[-1].strip()
                    
                row_data.append(purpose_main)
                row_data.append(purpose_note)
            
            # other cells can be inserted as normal
            else:
                row_data.append(cell_data)
                
        table_data.append(row_data)
    
    return(table_data)

# %%
def cache_to_csv(lst, path):

    no_rows = len(lst)
    
    with open(path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerows(lst)

    with open(path, 'r', newline='') as f:
        reader = csv.reader(f)
        check = list(reader)

    assert(len(lst) == len(check))
    
    print('LOG[INFO]: Wrote %s rows to %s' % (no_rows, path))

# %%
def make_html_path(parent_dir, call_sign, page_no):
    '''
    Helper function that generates path for caching html pages
    '''
    path = ("%s/%s-%s.html" % (parent_dir, call_sign, str(page_no).zfill(3)))
    return path

# %%
make_html_path('cake', 'is', '4')
# Out:
# 'cake/is-004.html'

# %%
def scrape_tables_for_call_sign(call_sign, html_cache, csv_cache, without_browser=False):
    """
    Scrapes the FCC Application Search database for a given call sign.
    
    Caches results pages as HTML
    
    Returns the table as a list of lists, for example:
    [
      ['File Number', 'Call Sign/Lease ID', 'Applicant Name', 'FRN', 'Purpose_Main', 'Purpose_Note', 'Radio Service', 'Receipt Date', 'Status'],
      ['0000214527',  'KNKN555',            'AT&T',           '',    'Amendment',    'Transfer Control', 'AL',        '09/05/2000',   'Granted'],
      ...,
      ...
    ]
    
    """
    tick = time.time()
    print("LOG[INFO]: START %s " % call_sign)
    
    
    # driver config - start in private
    firefox_profile = webdriver.FirefoxProfile()
    firefox_profile.set_preference("browser.privatebrowsing.autostart", True)
    
    # (optional) don't open up browser
    firefox_options = Options()
    if without_browser:
        firefox_options.add_argument("--headless")
    
    # spin up the webdriver
    firefox = webdriver.Firefox(options=firefox_options, executable_path="./geckodriver")
    firefox.get("https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAdvanced.jsp")
    
    # specify the call sign that we want to scrape for
    callsign = firefox.find_element_by_id("ulsCallSign")
    callsign.send_keys(call_sign)
    
    # set pagination to 100 (maximum)
    pagination = Select(firefox.find_element_by_xpath("//select[@name='pageSize']"))
    pagination.select_by_visible_text("100")
    
    # submit the search form, wait for load
    # NOTE: find form submission by form element name, not search button image
    firefox.find_element_by_name("search").submit()
    WebDriverWait(firefox, 45).until(EC.url_changes("https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAdvanced.jsp"))
    WebDriverWait(firefox, 45).until(lambda _: firefox.execute_script("return document.readyState") == "complete")
    
    # extract and cache html from first page
    page = 1
    innerHTML = firefox.execute_script("return document.body.innerHTML")
    with open(make_html_path(html_cache, call_sign, page), 'w') as f:
        f.write(innerHTML)
    
    # store count of search results for later check
    no_results = count_results(innerHTML)
    
    # Scrape results data from first page
    search_data = []
    search_data += scrape_table_page(innerHTML)
    
    # as long there is a link to "next page"...
    next_page_xpath = "//*[@title='Next page of results']"
    while element_exists(firefox, next_page_xpath):
        # ... go to next page
        firefox.find_element_by_xpath(next_page_xpath).click()
        # ... wait for load
        WebDriverWait(firefox, 45).until(lambda _: firefox.execute_script("return document.readyState") == "complete")
        # .. increment page counter, extract and cache html 
        page += 1
        innerHTML = firefox.execute_script("return document.body.innerHTML")
        with open(make_html_path(html_cache, call_sign, page), 'w') as f:
            f.write(innerHTML)
        # ... scrape and add page results to all results
        search_data += scrape_table_page(innerHTML)

    # gracefully close the webdriver
    firefox.quit()
    
    # Check that all results have been scraped
    no_rows = len(search_data)
    #assert(no_rows == no_results)
    print("LOG[INFO]: Scraped %s rows out of %s results" % (no_rows, no_results))

    # Cache search results table to csv (all results from all pages)
    csv_path = ''.join([csv_cache, call_sign, ".csv"])
    cache_to_csv(search_data, csv_path)
    

    tock = time.time()
    print("LOG[INFO]: END %s (%2f seconds)" % (call_sign, tock - tick))
    
    return search_data

# %% [markdown]
# ## Scrape the tables for a list of call signs (loop)

# %%
# read in list of all callsigns from file

callsign_path = 'data-cache/cma_callsign_lookup.csv'

callsigns = pd.read_csv(callsign_path).sort_values(by=['callsign_leaseID'])['callsign_leaseID'].tolist()
# Out:
# ['B',
#  'KNKA200',
#  'KNKA201',
#  'KNKA202',
#  'KNKA203',
#  'KNKA204',
#  'KNKA205',
#  'KNKA206',
#  'KNKA207',
#  'KNKA208',
#  'KNKA209',
#  'KNKA210',
#  'KNKA211',
#  'KNKA212',
#  'KNKA214',
#  'KNKA215',
#  'KNKA216',
#  'KNKA217',
#  'KNKA218',
#  'KNKA219',
#  'KNKA220',
#  'KNKA221',
#  'KNKA222',
#  'KNKA223',
#  'KNKA224',
#  'KNKA225',
#  'KNKA226',
#  'KNKA227',
#  'KNKA228',
#  'KNKA229',
#  'KNKA230',
#  'KNKA231',
#  'KNKA232',
#  'KNKA233',
#  'KNKA234',
#  'KNKA235',
#  'KNKA236',
#  'KNKA237',
#  'KNKA238',
#  'KNKA239',
#  'KNKA240',
#  'KNKA241',
#  'KNKA242',
#  'KNKA243',
#  'KNKA244',
#  'KNKA245',
#  'KNKA246',
#  'KNKA247',
#  'KNKA248',
#  'KNKA249',
#  'KNKA250',
#  'KNKA251',
#  'KNKA252',
#  'KNKA253',
#  'KNKA254',
#  'KNKA255',
#  'KNKA256',
#  'KNKA257',
#  'KNKA258',
#  'KNKA259',
#  'KNKA260',
#  'KNKA261',
#  'KNKA262',
#  'KNKA263',
#  'KNKA264',
#  'KNKA265',
#  'KNKA266',
#  'KNKA267',
#  'KNKA268',
#  'KNKA269',
#  'KNKA270',
#  'KNKA271',
#  'KNKA272',
#  'KNKA273',
#  'KNKA274',
#  'KNKA275',
#  'KNKA276',
#  'KNKA277',
#  'KNKA278',
#  'KNKA279',
#  'KNKA280',
#  'KNKA281',
#  'KNKA282',
#  'KNKA283',
#  'KNKA284',
#  'KNKA285',
#  'KNKA286',
#  'KNKA287',
#  'KNKA288',
#  'KNKA289',
#  'KNKA290',
#  'KNKA291',
#  'KNKA292',
#  'KNKA293',
#  'KNKA294',
#  'KNKA295',
#  'KNKA296',
#  'KNKA297',
#  'KNKA298',
#  'KNKA299',
#  'KNKA300',
#  'KNKA301',
#  'KNKA302',
#  'KNKA303',
#  'KNKA304',
#  'KNKA305',
#  'KNKA306',
#  'KNKA307',
#  'KNKA308',
#  'KNKA309',
#  'KNKA310',
#  'KNKA311',
#  'KNKA312',
#  'KNKA313',
#  'KNKA314',
#  'KNKA315',
#  'KNKA316',
#  'KNKA317',
#  'KNKA318',
#  'KNKA319',
#  'KNKA320',
#  'KNKA321',
#  'KNKA322',
#  'KNKA323',
#  'KNKA324',
#  'KNKA325',
#  'KNKA326',
#  'KNKA327',
#  'KNKA328',
#  'KNKA329',
#  'KNKA330',
#  'KNKA331',
#  'KNKA332',
#  'KNKA333',
#  'KNKA334',
#  'KNKA335',
#  'KNKA336',
#  'KNKA337',
#  'KNKA338',
#  'KNKA339',
#  'KNKA340',
#  'KNKA341',
#  'KNKA342',
#  'KNKA343',
#  'KNKA344',
#  'KNKA345',
#  'KNKA346',
#  'KNKA347',
#  'KNKA348',
#  'KNKA349',
#  'KNKA350',
#  'KNKA351',
#  'KNKA352',
#  'KNKA353',
#  'KNKA354',
#  'KNKA355',
#  'KNKA356',
#  'KNKA357',
#  'KNKA358',
#  'KNKA359',
#  'KNKA360',
#  'KNKA361',
#  'KNKA362',
#  'KNKA363',
#  'KNKA364',
#  'KNKA365',
#  'KNKA366',
#  'KNKA367',
#  'KNKA368',
#  'KNKA369',
#  'KNKA370',
#  'KNKA371',
#  'KNKA372',
#  'KNKA373',
#  'KNKA374',
#  'KNKA375',
#  'KNKA376',
#  'KNKA378',
#  'KNKA379',
#  'KNKA380',
#  'KNKA381',
#  'KNKA382',
#  'KNKA383',
#  'KNKA384',
#  'KNKA385',
#  'KNKA386',
#  'KNKA387',
#  'KNKA388',
#  'KNKA389',
#  'KNKA390',
#  'KNKA391',
#  'KNKA392',
#  'KNKA393',
#  'KNKA394',
#  'KNKA395',
#  'KNKA396',
#  'KNKA397',
#  'KNKA398',
#  'KNKA399',
#  'KNKA400',
#  'KNKA401',
#  'KNKA402',
#  'KNKA403',
#  'KNKA404',
#  'KNKA405',
#  'KNKA406',
#  'KNKA407',
#  'KNKA408',
#  'KNKA409',
#  'KNKA410',
#  'KNKA411',
#  'KNKA412',
#  'KNKA413',
#  'KNKA414',
#  'KNKA415',
#  'KNKA416',
#  'KNKA417',
#  'KNKA418',
#  'KNKA419',
#  'KNKA420',
#  'KNKA421',
#  'KNKA422',
#  'KNKA423',
#  'KNKA424',
#  'KNKA425',
#  'KNKA426',
#  'KNKA427',
#  'KNKA428',
#  'KNKA429',
#  'KNKA430',
#  'KNKA431',
#  'KNKA432',
#  'KNKA433',
#  'KNKA434',
#  'KNKA435',
#  'KNKA436',
#  'KNKA437',
#  'KNKA438',
#  'KNKA439',
#  'KNKA440',
#  'KNKA441',
#  'KNKA442',
#  'KNKA443',
#  'KNKA444',
#  'KNKA445',
#  'KNKA446',
#  'KNKA447',
#  'KNKA448',
#  'KNKA449',
#  'KNKA450',
#  'KNKA451',
#  'KNKA452',
#  'KNKA453',
#  'KNKA454',
#  'KNKA455',
#  'KNKA456',
#  'KNKA457',
#  'KNKA458',
#  'KNKA459',
#  'KNKA460',
#  'KNKA461',
#  'KNKA462',
#  'KNKA463',
#  'KNKA464',
#  'KNKA465',
#  'KNKA466',
#  'KNKA467',
#  'KNKA468',
#  'KNKA469',
#  'KNKA470',
#  'KNKA471',
#  'KNKA472',
#  'KNKA473',
#  'KNKA474',
#  'KNKA475',
#  'KNKA476',
#  'KNKA477',
#  'KNKA478',
#  'KNKA479',
#  'KNKA480',
#  'KNKA481',
#  'KNKA482',
#  'KNKA483',
#  'KNKA484',
#  'KNKA485',
#  'KNKA486',
#  'KNKA487',
#  'KNKA488',
#  'KNKA489',
#  'KNKA490',
#  'KNKA491',
#  'KNKA492',
#  'KNKA493',
#  'KNKA494',
#  'KNKA495',
#  'KNKA496',
#  'KNKA497',
#  'KNKA498',
#  'KNKA499',
#  'KNKA500',
#  'KNKA501',
#  'KNKA502',
#  'KNKA503',
#  'KNKA504',
#  'KNKA505',
#  'KNKA506',
#  'KNKA507',
#  'KNKA508',
#  'KNKA509',
#  'KNKA510',
#  'KNKA511',
#  'KNKA512',
#  'KNKA513',
#  'KNKA514',
#  'KNKA515',
#  'KNKA516',
#  'KNKA517',
#  'KNKA518',
#  'KNKA519',
#  'KNKA520',
#  'KNKA521',
#  'KNKA522',
#  'KNKA523',
#  'KNKA524',
#  'KNKA525',
#  'KNKA526',
#  'KNKA527',
#  'KNKA528',
#  'KNKA529',
#  'KNKA530',
#  'KNKA531',
#  'KNKA532',
#  'KNKA533',
#  'KNKA534',
#  'KNKA535',
#  'KNKA536',
#  'KNKA537',
#  'KNKA538',
#  'KNKA539',
#  'KNKA540',
#  'KNKA541',
#  'KNKA542',
#  'KNKA543',
#  'KNKA544',
#  'KNKA545',
#  'KNKA546',
#  'KNKA547',
#  'KNKA548',
#  'KNKA549',
#  'KNKA550',
#  'KNKA551',
#  'KNKA552',
#  'KNKA553',
#  'KNKA554',
#  'KNKA555',
#  'KNKA556',
#  'KNKA557',
#  'KNKA558',
#  'KNKA559',
#  'KNKA560',
#  'KNKA561',
#  'KNKA562',
#  'KNKA563',
#  'KNKA564',
#  'KNKA565',
#  'KNKA566',
#  'KNKA567',
#  'KNKA568',
#  'KNKA569',
#  'KNKA570',
#  'KNKA571',
#  'KNKA572',
#  'KNKA573',
#  'KNKA574',
#  'KNKA575',
#  'KNKA576',
#  'KNKA577',
#  'KNKA578',
#  'KNKA579',
#  'KNKA580',
#  'KNKA581',
#  'KNKA582',
#  'KNKA583',
#  'KNKA584',
#  'KNKA585',
#  'KNKA586',
#  'KNKA587',
#  'KNKA588',
#  'KNKA589',
#  'KNKA590',
#  'KNKA591',
#  'KNKA592',
#  'KNKA593',
#  'KNKA594',
#  'KNKA595',
#  'KNKA597',
#  'KNKA598',
#  'KNKA599',
#  'KNKA600',
#  'KNKA601',
#  'KNKA602',
#  'KNKA603',
#  'KNKA604',
#  'KNKA605',
#  'KNKA606',
#  'KNKA607',
#  'KNKA608',
#  'KNKA609',
#  'KNKA610',
#  'KNKA611',
#  'KNKA612',
#  'KNKA613',
#  'KNKA614',
#  'KNKA615',
#  'KNKA616',
#  'KNKA617',
#  'KNKA618',
#  'KNKA619',
#  'KNKA620',
#  'KNKA621',
#  'KNKA622',
#  'KNKA623',
#  'KNKA624',
#  'KNKA625',
#  'KNKA626',
#  'KNKA627',
#  'KNKA628',
#  'KNKA629',
#  'KNKA630',
#  'KNKA631',
#  'KNKA632',
#  'KNKA633',
#  'KNKA634',
#  'KNKA635',
#  'KNKA636',
#  'KNKA637',
#  'KNKA638',
#  'KNKA639',
#  'KNKA640',
#  'KNKA641',
#  'KNKA642',
#  'KNKA643',
#  'KNKA644',
#  'KNKA645',
#  'KNKA646',
#  'KNKA647',
#  'KNKA648',
#  'KNKA649',
#  'KNKA650',
#  'KNKA651',
#  'KNKA652',
#  'KNKA653',
#  'KNKA654',
#  'KNKA655',
#  'KNKA656',
#  'KNKA657',
#  'KNKA658',
#  'KNKA659',
#  'KNKA660',
#  'KNKA661',
#  'KNKA662',
#  'KNKA663',
#  'KNKA664',
#  'KNKA665',
#  'KNKA666',
#  'KNKA667',
#  'KNKA668',
#  'KNKA669',
#  'KNKA670',
#  'KNKA671',
#  'KNKA672',
#  'KNKA673',
#  'KNKA674',
#  'KNKA675',
#  'KNKA676',
#  'KNKA677',
#  'KNKA678',
#  'KNKA679',
#  'KNKA680',
#  'KNKA681',
#  'KNKA682',
#  'KNKA683',
#  'KNKA684',
#  'KNKA685',
#  'KNKA686',
#  'KNKA687',
#  'KNKA688',
#  'KNKA689',
#  'KNKA690',
#  'KNKA691',
#  'KNKA692',
#  'KNKA693',
#  'KNKA694',
#  'KNKA695',
#  'KNKA696',
#  'KNKA697',
#  'KNKA698',
#  'KNKA700',
#  'KNKA701',
#  'KNKA702',
#  'KNKA703',
#  'KNKA704',
#  'KNKA705',
#  'KNKA706',
#  'KNKA707',
#  'KNKA708',
#  'KNKA709',
#  'KNKA710',
#  'KNKA711',
#  'KNKA712',
#  'KNKA713',
#  'KNKA714',
#  'KNKA715',
#  'KNKA716',
#  'KNKA717',
#  'KNKA718',
#  'KNKA719',
#  'KNKA720',
#  'KNKA721',
#  'KNKA722',
#  'KNKA723',
#  'KNKA724',
#  'KNKA725',
#  'KNKA726',
#  'KNKA727',
#  'KNKA728',
#  'KNKA729',
#  'KNKA730',
#  'KNKA731',
#  'KNKA732',
#  'KNKA733',
#  'KNKA734',
#  'KNKA735',
#  'KNKA736',
#  'KNKA737',
#  'KNKA738',
#  'KNKA739',
#  'KNKA740',
#  'KNKA741',
#  'KNKA742',
#  'KNKA743',
#  'KNKA744',
#  'KNKA745',
#  'KNKA746',
#  'KNKA747',
#  'KNKA748',
#  'KNKA749',
#  'KNKA750',
#  'KNKA751',
#  'KNKA752',
#  'KNKA753',
#  'KNKA754',
#  'KNKA755',
#  'KNKA756',
#  'KNKA757',
#  'KNKA758',
#  'KNKA759',
#  'KNKA760',
#  'KNKA761',
#  'KNKA762',
#  'KNKA763',
#  'KNKA764',
#  'KNKA765',
#  'KNKA766',
#  'KNKA768',
#  'KNKA769',
#  'KNKA770',
#  'KNKA772',
#  'KNKA773',
#  'KNKA774',
#  'KNKA775',
#  'KNKA776',
#  'KNKA777',
#  'KNKA778',
#  'KNKA779',
#  'KNKA780',
#  'KNKA781',
#  'KNKA782',
#  'KNKA783',
#  'KNKA784',
#  'KNKA785',
#  'KNKA786',
#  'KNKA787',
#  'KNKA788',
#  'KNKA790',
#  'KNKA791',
#  'KNKA792',
#  'KNKA794',
#  'KNKA795',
#  'KNKA796',
#  'KNKA797',
#  'KNKA798',
#  'KNKA799',
#  'KNKA802',
#  'KNKA803',
#  'KNKA804',
#  'KNKA805',
#  'KNKA806',
#  'KNKA807',
#  'KNKA808',
#  'KNKA809',
#  'KNKA810',
#  'KNKA811',
#  'KNKA812',
#  'KNKA813',
#  'KNKA814',
#  'KNKA815',
#  'KNKA816',
#  'KNKA817',
#  'KNKA818',
#  'KNKA819',
#  'KNKA820',
#  'KNKA822',
#  'KNKA823',
#  'KNKA824',
#  'KNKN200',
#  'KNKN201',
#  'KNKN202',
#  'KNKN203',
#  'KNKN204',
#  'KNKN205',
#  'KNKN206',
#  'KNKN207',
#  'KNKN208',
#  'KNKN209',
#  'KNKN210',
#  'KNKN211',
#  'KNKN212',
#  'KNKN213',
#  'KNKN214',
#  'KNKN215',
#  'KNKN216',
#  'KNKN217',
#  'KNKN218',
#  'KNKN219',
#  'KNKN220',
#  'KNKN221',
#  'KNKN222',
#  'KNKN223',
#  'KNKN224',
#  'KNKN225',
#  'KNKN226',
#  'KNKN227',
#  'KNKN228',
#  'KNKN229',
#  'KNKN230',
#  'KNKN231',
#  'KNKN232',
#  'KNKN233',
#  'KNKN234',
#  'KNKN235',
#  'KNKN236',
#  'KNKN237',
#  'KNKN238',
#  'KNKN239',
#  'KNKN240',
#  'KNKN241',
#  'KNKN242',
#  'KNKN243',
#  'KNKN244',
#  'KNKN245',
#  'KNKN246',
#  'KNKN247',
#  'KNKN248',
#  'KNKN249',
#  'KNKN250',
#  'KNKN251',
#  'KNKN252',
#  'KNKN253',
#  'KNKN254',
#  'KNKN255',
#  'KNKN256',
#  'KNKN257',
#  'KNKN258',
#  'KNKN259',
#  'KNKN260',
#  'KNKN261',
#  'KNKN262',
#  'KNKN263',
#  'KNKN264',
#  'KNKN265',
#  'KNKN266',
#  'KNKN267',
#  'KNKN268',
#  'KNKN269',
#  'KNKN270',
#  'KNKN271',
#  'KNKN272',
#  'KNKN273',
#  'KNKN274',
#  'KNKN275',
#  'KNKN276',
#  'KNKN277',
#  'KNKN278',
#  'KNKN279',
#  'KNKN280',
#  'KNKN281',
#  'KNKN282',
#  'KNKN283',
#  'KNKN284',
#  'KNKN285',
#  'KNKN286',
#  'KNKN287',
#  'KNKN288',
#  'KNKN289',
#  'KNKN290',
#  'KNKN291',
#  'KNKN292',
#  'KNKN293',
#  'KNKN294',
#  'KNKN295',
#  'KNKN296',
#  'KNKN297',
#  'KNKN298',
#  'KNKN300',
#  'KNKN301',
#  'KNKN302',
#  'KNKN303',
#  'KNKN304',
#  'KNKN305',
#  'KNKN306',
#  'KNKN307',
#  'KNKN308',
#  'KNKN309',
#  'KNKN310',
#  'KNKN311',
#  'KNKN312',
#  'KNKN313',
#  'KNKN314',
#  'KNKN315',
#  'KNKN316',
#  'KNKN317',
#  'KNKN318',
#  'KNKN319',
#  'KNKN320',
#  'KNKN321',
#  'KNKN322',
#  'KNKN323',
#  'KNKN324',
#  'KNKN325',
#  'KNKN326',
#  'KNKN327',
#  'KNKN328',
#  'KNKN329',
#  'KNKN330',
#  'KNKN331',
#  'KNKN332',
#  'KNKN333',
#  'KNKN334',
#  'KNKN335',
#  'KNKN336',
#  'KNKN337',
#  'KNKN338',
#  'KNKN339',
#  'KNKN340',
#  'KNKN341',
#  'KNKN342',
#  'KNKN343',
#  'KNKN344',
#  'KNKN345',
#  'KNKN346',
#  'KNKN347',
#  'KNKN348',
#  'KNKN349',
#  'KNKN350',
#  'KNKN351',
#  'KNKN352',
#  'KNKN353',
#  'KNKN354',
#  'KNKN355',
#  'KNKN356',
#  'KNKN357',
#  'KNKN358',
#  'KNKN359',
#  'KNKN360',
#  'KNKN361',
#  'KNKN362',
#  'KNKN363',
#  'KNKN364',
#  'KNKN365',
#  'KNKN366',
#  'KNKN367',
#  'KNKN368',
#  'KNKN369',
#  'KNKN370',
#  'KNKN371',
#  'KNKN372',
#  'KNKN373',
#  'KNKN374',
#  'KNKN375',
#  'KNKN376',
#  'KNKN377',
#  'KNKN378',
#  'KNKN379',
#  'KNKN380',
#  'KNKN381',
#  'KNKN382',
#  'KNKN383',
#  'KNKN384',
#  'KNKN385',
#  'KNKN386',
#  'KNKN387',
#  'KNKN388',
#  'KNKN389',
#  'KNKN390',
#  'KNKN391',
#  'KNKN392',
#  'KNKN393',
#  'KNKN394',
#  'KNKN395',
#  'KNKN396',
#  'KNKN397',
#  'KNKN398',
#  'KNKN399',
#  'KNKN400',
#  'KNKN401',
#  'KNKN402',
#  'KNKN403',
#  'KNKN404',
#  'KNKN405',
#  'KNKN406',
#  'KNKN407',
#  'KNKN408',
#  'KNKN409',
#  'KNKN410',
#  'KNKN411',
#  'KNKN412',
#  'KNKN413',
#  'KNKN414',
#  'KNKN415',
#  'KNKN416',
#  'KNKN417',
#  'KNKN418',
#  'KNKN419',
#  'KNKN420',
#  'KNKN421',
#  'KNKN422',
#  'KNKN423',
#  'KNKN424',
#  'KNKN425',
#  'KNKN426',
#  'KNKN427',
#  'KNKN428',
#  'KNKN429',
#  'KNKN430',
#  'KNKN431',
#  'KNKN432',
#  'KNKN433',
#  'KNKN434',
#  'KNKN435',
#  'KNKN436',
#  'KNKN437',
#  'KNKN438',
#  'KNKN439',
#  'KNKN440',
#  'KNKN441',
#  'KNKN442',
#  'KNKN443',
#  'KNKN444',
#  'KNKN445',
#  'KNKN446',
#  'KNKN447',
#  'KNKN448',
#  'KNKN449',
#  'KNKN450',
#  'KNKN451',
#  'KNKN452',
#  'KNKN453',
#  'KNKN454',
#  'KNKN455',
#  'KNKN456',
#  'KNKN457',
#  'KNKN458',
#  'KNKN459',
#  'KNKN460',
#  'KNKN461',
#  'KNKN462',
#  'KNKN463',
#  'KNKN464',
#  'KNKN465',
#  'KNKN466',
#  'KNKN467',
#  'KNKN468',
#  'KNKN469',
#  'KNKN470',
#  'KNKN471',
#  'KNKN472',
#  'KNKN473',
#  'KNKN474',
#  'KNKN475',
#  'KNKN476',
#  'KNKN477',
#  'KNKN478',
#  'KNKN479',
#  'KNKN480',
#  'KNKN481',
#  'KNKN482',
#  'KNKN483',
#  'KNKN484',
#  'KNKN485',
#  'KNKN486',
#  'KNKN487',
#  'KNKN488',
#  'KNKN489',
#  'KNKN490',
#  'KNKN491',
#  'KNKN492',
#  'KNKN493',
#  'KNKN494',
#  'KNKN495',
#  'KNKN496',
#  'KNKN497',
#  'KNKN498',
#  'KNKN499',
#  'KNKN500',
#  'KNKN501',
#  'KNKN502',
#  'KNKN503',
#  'KNKN504',
#  'KNKN505',
#  'KNKN506',
#  'KNKN507',
#  'KNKN508',
#  'KNKN509',
#  'KNKN510',
#  'KNKN511',
#  'KNKN512',
#  'KNKN513',
#  'KNKN514',
#  'KNKN515',
#  'KNKN516',
#  'KNKN517',
#  'KNKN518',
#  'KNKN519',
#  'KNKN520',
#  'KNKN521',
#  'KNKN522',
#  'KNKN523',
#  'KNKN524',
#  'KNKN525',
#  'KNKN526',
#  'KNKN527',
#  'KNKN528',
#  'KNKN529',
#  'KNKN530',
#  'KNKN531',
#  'KNKN532',
#  'KNKN533',
#  'KNKN534',
#  'KNKN535',
#  'KNKN536',
#  'KNKN537',
#  'KNKN538',
#  'KNKN539',
#  'KNKN540',
#  'KNKN541',
#  'KNKN542',
#  'KNKN543',
#  'KNKN544',
#  'KNKN545',
#  'KNKN546',
#  'KNKN547',
#  'KNKN548',
#  'KNKN549',
#  'KNKN550',
#  'KNKN551',
#  'KNKN552',
#  'KNKN553',
#  'KNKN554',
#  'KNKN555',
#  'KNKN556',
#  'KNKN557',
#  'KNKN558',
#  'KNKN559',
#  'KNKN560',
#  'KNKN561',
#  'KNKN562',
#  'KNKN563',
#  'KNKN564',
#  'KNKN565',
#  'KNKN566',
#  'KNKN567',
#  'KNKN568',
#  'KNKN569',
#  'KNKN570',
#  'KNKN571',
#  'KNKN572',
#  'KNKN573',
#  'KNKN574',
#  'KNKN575',
#  'KNKN576',
#  'KNKN577',
#  'KNKN578',
#  'KNKN579',
#  'KNKN580',
#  'KNKN581',
#  'KNKN582',
#  'KNKN583',
#  'KNKN584',
#  'KNKN585',
#  ...]

# %%
tick = time.time()
print("LOG[INFO]: START TIME is %s\n" % (time.strftime("%I:%M %p")))

tries = 0
max_tries = 5

start_index = 1

for cs in callsigns[start_index:2]:    
    if tries <= max_tries:
        try:
            scrape_tables_for_call_sign(cs, html_cache, csv_cache, without_browser=False)
            pause = (random.randint(1,30))
        except Exception as e:
            tries += 1
            print("Error at %s, located at callsigns[%s]" % (cs, callsigns.index(cs)))
            pause = (random.randint(200,300) * math.sqrt(tries))
        finally:
            time.sleep(pause)
    else:
        break

tock = time.time()
print("LOG[INFO]: END")
# Out:
# LOG[INFO]: START TIME is 03:34 PM
#
# LOG[INFO]: START KNKA200
# LOG[INFO]: Scraped 266 rows out of 266 results
# Wrote 266 rows to path: search-cache/apps-by-callsign/csv/KNKA200.csv
# LOG[INFO]: END KNKA200 (15.721977 seconds)
# LOG[INFO]: END

# %%
# read in the list of FCC callsigns
call_signs = ["KNKN555", "KNKN556"]
call_signs = ["KNKA456"]
call_signs = ["KNKA455", "KNKA454"]
call_signs = ["KNKN776", "KNKN775"]
html_cache = 'search-cache/apps-by-callsign/html'
csv_cache = 'search-cache/apps-by-callsign/csv/'

# %%
# collects the scraped data for *all* the call signs into a python list of lists
scraped_data = []
for cs in call_signs:
    scraped_data.append(
        scrape_tables_for_call_sign(cs, html_cache, csv_cache, without_browser=False)
    )
# Out:
# LOG[INFO]: START KNKN776
# LOG[INFO]: Scraped 42 rows out of 42 results
# Wrote 42 rows to path: search-cache/apps-by-callsign/csv/KNKN776.csv
# LOG[INFO]: END KNKN776 (15.651379 seconds)
# LOG[INFO]: START KNKN775
# LOG[INFO]: Scraped 21 rows out of 21 results
# Wrote 21 rows to path: search-cache/apps-by-callsign/csv/KNKN775.csv
# LOG[INFO]: END KNKN775 (16.539492 seconds)

# %%
# sanity check over the data for size of scraped data, and dimensions of callsign tables
assert(len(scraped_data) == len(call_signs))
pd.DataFrame(scraped_data[0])
# Out:
#           0            1        2                                     3  \
# 0      None         None     None                                  None
# 1   KNKA456   0000004285  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 2   KNKA456   0000011015  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 3   KNKA456   0000015805  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 4   KNKA456   0000015852  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 5   KNKA456   0000018591  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 6   KNKA456   0000025338  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 7   KNKA456   0000077568  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 8   KNKA456  00001CLMP88  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 9   KNKA456   0000244304  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 10  KNKA456   0000270713  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 11  KNKA456   0000316894  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 12  KNKA456   0000372856  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 13  KNKA456   0000410832  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 14  KNKA456   0000506386  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 15  KNKA456   0000771236  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 16  KNKA456   0000838403  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 17  KNKA456   0002969917  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 18  KNKA456   0003006261  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 19  KNKA456   0003085473  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 20  KNKA456   0003245171  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 21  KNKA456   0003798949                     USCOC OF GREATER IOWA, LLC
# 22  KNKA456   0005387436  KNKA456            USCOC OF GREATER IOWA, LLC
# 23  KNKA456   0007989503  KNKA456            USCOC OF GREATER IOWA, LLC
# 24  KNKA456  00377CLML96  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 25  KNKA456  00405CLML88  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 26  KNKA456  00531CLML98  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 27  KNKA456  00643CLML98  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 28  KNKA456  00897CLML96  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 29  KNKA456  01016CLML93  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 30  KNKA456  01250CLML98  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 31  KNKA456  01923CLML88  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 32  KNKA456  02329CLML89  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 33  KNKA456  02896CLMP92  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 34  KNKA456  03007CLML98  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 35  KNKA456  03049CLTC89  KNKA456
# 36  KNKA456  03058CLML97  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 37  KNKA456  03482CLML93  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 38  KNKA456  03873CLML98  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 39  KNKA456  04029CLML97  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 40  KNKA456  04354CLMR97  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 41  KNKA456  05344CLML92  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 42  KNKA456  06791CLMP92  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 43  KNKA456  07147CLML91  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 44  KNKA456  07405CLMP91  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 45  KNKA456  07752CLML95  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 46  KNKA456  08559CLML91  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
# 47  KNKA456  60245CLMP99  KNKA456  DAVENPORT CELLULAR TELEPHONE COMPANY
#
#              4                            5     6     7           8  \
# 0         None                         None  None  None        None
# 1   0001702190                 Modification          CL  12/21/1998
# 2   0001702190                 Modification          CL  11/12/1998
# 3   0001702190                 Modification          CL  04/21/1999
# 4   0001702190                 Modification          CL  05/02/1999
# 5   0001702190                 Modification          CL  08/18/1999
# 6   0001702190                 Modification          CL  09/16/1999
# 7   0001702190                 Modification          CL  02/04/2000
# 8   0001702190                          New          CL  10/01/1987
# 9   0001702190                 Modification          CL  10/23/2000
# 10  0001702190                 Modification          CL  11/22/2000
# 11  0001702190                 Modification          CL  01/08/2001
# 12  0001702190                 Modification          CL  02/20/2001
# 13  0001702190                 Modification          CL  03/28/2001
# 14  0001702190                 Modification          CL  06/29/2001
# 15  0001702190                 Modification          CL  02/13/2002
# 16  0001702190                 Modification          CL  04/05/2002
# 17  0001702190        Administrative Update          CL  03/28/2007
# 18  0001702190        Administrative Update          CL  04/26/2007
# 19  0001702190                 Modification          CL  06/25/2007
# 20  0001702190                 Renewal Only          CL  11/30/2007
# 21  0018420067  Assignment of Authorization          AL  04/07/2009
# 22  0018420067        Administrative Update          CL  09/11/2012
# 23  0018420067                 Renewal Only          CL  11/09/2017
# 24  0001702190                 Modification          CL  10/23/1995
# 25  0001702190                 Modification          CL  12/21/1987
# 26  0001702190                 Modification          CL  11/07/1997
# 27  0001702190                 Modification          CL  11/14/1997
# 28  0001702190                 Modification          CL  11/22/1995
# 29  0001702190                 Modification          CL  12/04/1992
# 30  0001702190                 Modification          CL  01/13/1998
# 31  0001702190                 Modification          CL  09/07/1988
# 32  0001702190                 Modification          CL  11/16/1988
# 33  0001702190                          New          CL  11/12/1991
# 34  0001702190                 Modification          CL  06/22/1998
# 35                      Transfer of Control          CL  04/11/1989
# 36  0001702190                 Modification          CL  06/23/1997
# 37  0001702190                 Modification          CL  05/14/1993
# 38  0001702190                 Modification          CL  09/09/1998
# 39  0001702190                 Modification          CL  09/11/1997
# 40  0001702190                 Renewal Only          CL  09/11/1997
# 41  0001702190                 Modification          CL  04/07/1992
# 42  0001702190                          New          CL  06/18/1992
# 43  0001702190                 Modification          CL  10/23/1990
# 44  0001702190                          New          CL  11/16/1990
# 45  0001702190                 Modification          CL  09/21/1995
# 46  0001702190                 Modification          CL  02/20/1991
# 47  0001702190                          New          CL  01/01/1980
#
#               9
# 0          None
# 1       Granted
# 2       Granted
# 3       Granted
# 4       Granted
# 5       Granted
# 6       Granted
# 7       Granted
# 8       Granted
# 9     Dismissed
# 10      Granted
# 11      Granted
# 12      Granted
# 13      Granted
# 14      Granted
# 15      Granted
# 16      Granted
# 17      Granted
# 18      Granted
# 19      Granted
# 20      Granted
# 21     Accepted
# 22      Granted
# 23      Granted
# 24      Granted
# 25      Granted
# 26      Granted
# 27      Granted
# 28      Granted
# 29      Granted
# 30      Granted
# 31      Granted
# 32      Granted
# 33    Dismissed
# 34      Granted
# 35  Consummated
# 36      Granted
# 37      Granted
# 38      Granted
# 39      Granted
# 40      Granted
# 41      Granted
# 42      Granted
# 43      Granted
# 44      Granted
# 45      Granted
# 46      Granted
# 47      Granted

# %%
# last row of first scraped call-sign
for row in scraped_data[0][-1:]:
    print(row)
# Out:
# ['KNKA456', '60245CLMP99', 'KNKA456', 'DAVENPORT CELLULAR TELEPHONE COMPANY', '0001702190', 'New', '', 'CL', '01/01/1980', 'Granted']

# %%
# print first 10 rows of second scraped callsign
for row in scraped_data[1][:10]:
    print(row)
# Out:
# []
# ['0000386266', '', 'AT&T Wireless Services, Inc.', '0004122032', 'Transfer of Control', '', 'AL', '03/05/2001', 'Granted']
# ['0000388274', 'KNKN556', 'Pennsylvania Cellular Telephone Corp.', '0001944032', 'Administrative Update', '', 'CL', '03/06/2001', 'Granted']
# ['0000547695', '', 'AT&T Wireless Services, Inc.', '0004122032', 'Transfer of Control', '', 'AL', '08/02/2001', 'Granted']
# ['0000591187', 'KNKN556', 'Pennsylvania Cellular Telephone Corp.', '0001944032', 'Renewal/Modification', '', 'CL', '09/13/2001', 'Granted']
# ['0000788563', 'KNKN556', 'Pennsylvania Cellular Telephone Corp.', '0001944032', 'Administrative Update', '', 'CL', '02/27/2002', 'Granted']
# ['0001093516', 'KNKN556', 'Pennsylvania Cellular Telephone Corp.', '0001944032', 'Administrative Update', '', 'CL', '11/18/2002', 'Granted']
# ['0001178597', '', 'Winston, LLC', '0003297520', 'Transfer of Control', '', 'AL', '01/29/2003', 'Granted']
# ['0001179154', '', 'Vanguard Cellular Pennsylvania, LLC', '0001944032', 'Assignment of Authorization', '', 'AL', '01/30/2003', 'Granted']
# ['0001656573', '', 'Cingular Wireless Corporation', '0005823844', 'Transfer of Control', '', 'AL', '03/18/2004', 'Inactive']

# %% [markdown]
# # [TODO]Output scrapped data
# * include readme in folder for column names
# * save each table as callsign.csv
# * note: empty value for call-sign --> part of larger transaction; see "Licenses" tab for list of all callsigns involved in transaction (only for newer applications)

# %% [markdown]
# # - Ignore below this line -
#
# This is code that's probably worth keeping as as reference for now -- in case it gives us insight into solving any bugs we run into. But you can ignore it when you run the scraper.

# %% [markdown]
# ### Read Me
# Notes:
# * find submit button using form element name, not submit image button
# Reference links:
# * http://jonathansoma.com/lede/foundations/classes/friday%20sessions/advanced-scraping-form-submissions-completed/

# %%
def scrape_table_for_call_sign(call_sign):
    
    # driver config - start in private
    firefox_profile = webdriver.FirefoxProfile()
    firefox_profile.set_preference("browser.privatebrowsing.autostart", True)
    
    firefox = webdriver.Firefox(executable_path="./geckodriver")
    firefox.get("https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAdvanced.jsp")
    
    # fill in the text input
    callsign = firefox.find_element_by_id("ulsCallSign")
    callsign.send_keys(call_sign)
    
    # set pagination to 100 (maximum)
    pagination = Select(firefox.find_element_by_xpath("//select[@name='pageSize']"))
    pagination.select_by_visible_text("10")
    
    # submit the search form, wait for load
    firefox.find_element_by_name("search").submit()
    WebDriverWait(firefox, 15).until(EC.url_changes("https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAdvanced.jsp"))
    WebDriverWait(firefox, 15).until(lambda _: firefox.execute_script("return document.readyState") == "complete")
    
    #print(firefox.page_source.encode("utf-8"))
    
    #innerHTML = firefox.execute_script("return document.body.innerHTML")
    #print(innerHTML)
    
    # find the link the next page if it exists
    firefox.find_element_by_xpath("//*[@title='Next page of results']").click()

    #next_link = firefox.find_element_by_xpath("//*[@title=\"Next page of results\"][0]")
    #next_link = firefox.find_element_by_xpath("//a[@title='Next page of results']")
    #print(next_link)
    
    #page_links = firefox.find_element_by_xpath("//a[@href]")
    #print(page_links)
    
    # count the number of pages we need to iterate through
    #pages = firefox.find_element_by_xpath("//*[contains(@title, 'Page')]")
    #pages = firefox.find_element_by_css_selector("//[title*='Page']")
    #print(pages)
    
    # gracefully close the webdriver
    time.sleep(10)
    firefox.quit()

# %%
scrape_table_for_call_sign("KNKN555")

# %%
firefox = webdriver.Firefox(executable_path="./geckodriver")
firefox.get("https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAdvanced.jsp")

# fill in the text input
callsign = firefox.find_element_by_id("ulsCallSign")
callsign.send_keys("KNKN555")

# fill in the dropdown
#dropdown= firefox.find_element_by_id("radioServiceCode")
#dropdown.send_keys("CL - Cellular")

# pagination to max
display = firefox.find_element_by_id("ulsRowsPerPage")
display.send_keys(100)

# submit form
firefox.find_element_by_name("search").submit()
WebDriverWait(firefox, 15).until(EC.url_changes("https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAdvanced.jsp"))
#test = WebDriverWait(firefox, 3).until(EC.staleness_of((By.ID, 'ulsCallSign')))
#test = firefox.implicitly_wait(10);

print(firefox.execute_script("return document.readyState"))

WebDriverWait(firefox, 15).until( lambda _: firefox.execute_script("return document.readyState") == "complete")
print(firefox.current_url)

# scrape out the table
#print(firefox.page_source.encode("utf-8"))
innerHTML = firefox.execute_script("return document.body.innerHTML")
print(innerHTML)

time.sleep(30)
firefox.quit()

# %%
ffx = Firefox(executable_path="./geckodriver")
request_data = {
    "basicSearchType": "basicSearchCallSign",
    "basicSearchTerm": "KNKN555",
    "x": "24",
    "y": "4",
    "exactMatchInd": "Y",
    "jsValidated" : "true",
    "currentPage": "searchAppl.jsp",
    "actionElement": "actionApplicationSearch"
}
ffx.request("POST",
    "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/ApplSearchController",
    data=request_data)

# %%
options = Options()  
#options.add_argument("--headless")  
chrome = webdriver.Chrome("./chromedriver")
chrome.get("www.google.com.au")
#chrome.request("GET", "https://www.google.com.au")
#chrome.request("GET", "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAppl.jsp")

# %%
referrer = "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/searchAppl.jsp"
headers = { "referrer" : referrer }
payload = {
    "basicSearchType": "basicSearchCallSign",
    "basicSearchTerm": "KNKN555",
    "x": 24,
    "y": 4,
    "exactMatchInd": "Y",
    "jsValidated" : "true",
    "currentPage": "searchAppl.jsp",
    "actionElement": "actionApplicationSearch"
}

res = requests.post(
    "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/ApplSearchController",
    data=payload,
    headers=headers,
)

# %%
res.history[1].url

# %%
options = Options()  
#options.add_argument("--headless")  
chrome = Chrome("./chromedriver", options=options)
chrome.request("GET", "https://www.fcc.gov/")

# %%
chrome.request("GET", "https://www.fcc.gov/")

# %%
request_data = {
    "basicSearchType": "basicSearchCallSign",
    "basicSearchTerm": "KNKN555",
    "x": 24,
    "y": 4,
    "exactMatchInd": "Y",
    "jsValidated" : "true",
    "currentPage": "searchAppl.jsp",
    "actionElement": "actionApplicationSearch"
}

res = chrome.request(
    "POST",
    "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/ApplSearchController",
    data=request_data
)

# %%
chrome = Chrome("./chromedriver")
response = chrome.request(
    "POST",
    "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/ApplSearchController",
    data={
        "basicSearchType": "basicSearchCallSign",
        "basicSearchTerm": "KNKN555",
        "x": 24,
        "y": 4,
        "exactMatchInd": "Y",
        "jsValidated" : "true",
        "currentPage": "searchAppl.jsp",
        "actionElement": "actionApplicationSearch"
    }
)

# %%
response = chrome.request(
    "GET",
    "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/results.jsp?applSearchKey=applSearchKey2019321143892"
)

# %%
res = requests.post(
    "https://wireless2.fcc.gov/UlsApp/ApplicationSearch/ApplSearchController",
    data={
        "basicSearchType": "basicSearchCallSign",
        "basicSearchTerm": "KNKN555",
        "x": "24",
        "y": "4",
        "exactMatchInd": "Y",
        "jsValidated" : "true",
        "currentPage": "searchAppl.jsp",
        "actionElement": "actionApplicationSearch"
    }
)
