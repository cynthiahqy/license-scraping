# %% [markdown]
# # Merge CallSign, CMA and Location

# %%
import pandas as pd
import re

# %%
import csv
import os

# %% [markdown]
# ## References
#
# `re.`:
# * https://medium.com/factory-mind/regex-tutorial-a-simple-cheatsheet-by-examples-649dc1c3f285
# * https://docs.python.org/3/library/re.
# * https://docs.python.org/3/howto/regex.html#regex-howto
# * https://www.journaldev.com/23763/python-remove-spaces-from-string
#
# `csv.`:
# * https://docs.python.org/3/library/csv.html#csv-fmt-params

# %% [markdown]
# ## Create Table of CMA number, area name, state
# * note CMA001 - CMA306 are MSA (Metropolitan Service Areas)
# * CMA307 onwards are RSA (Rural Service Areas)

# %%
path_to_csv_files = "data-cache/"

path_to_dropdown = ("%s/cma-dropdown_list.csv" % path_to_csv_files)
path_to_cmacnty = ("%s/cmacnty1990.xls" % path_to_csv_files)

# %%
# import cma_dropdown from csv
with open(path_to_dropdown, newline='\n') as f:
    reader = csv.reader(f, delimiter='-')
    m_dropdown = list(reader)

# %%
# split cma_no into first col
dropdown = []
for row in m_dropdown[1:]:
    dropdown.append([row[0].strip(), '-'.join(row[1:]).strip()])
dropdown[:10]
# Out:
# [['CMA001', 'New York, NY-NJ/Nassau-Suffolk'],
#  ['CMA002', 'Los Angeles-Long Beach/Anaheim'],
#  ['CMA003', 'Chicago, IL'],
#  ['CMA004', 'Philadelphia, PA'],
#  ['CMA005', 'Detroit/Ann Arbor, MI'],
#  ['CMA006', 'Boston-Lowell-Brockton-Lawrence-Haverhill, MA-NH'],
#  ['CMA007', 'San Francisco-Oakland, CA'],
#  ['CMA008', 'Washington, DC-MD-VA'],
#  ['CMA009', 'Dallas-Fort Worth, TX'],
#  ['CMA010', 'Houston, TX']]

# %%
# check striped line matches original dropdown item

with open(path_to_dropdown, "r") as f:
    test_line = f.readlines()[1].strip()
    
assert(test_line == ' - '.join(dropdown[0]))

# %%
# add MSA/RSA variable at i=306 

for row in dropdown[:306]:
    row.append('MSA')
for row in dropdown[306:]:
    row.append('RSA')

# %%
# check RSA strings don't have any state codes
pattern_statecode = '[A-Z]{2}'

re_bool_statecode = []

for row in dropdown[306:]:
    string = row[1]
    re_bool_statecode.append(bool(re.search(pattern_statecode,string)))

assert(sum(re_bool_statecode) == 0)

# %%
# extract and append state codes for some MSAs

for row in dropdown:
    string = row[1]
    row.append(re.findall(pattern_statecode, string))

# %%
# check MSA strings don't have any state numbers

pattern_statenum = '\d'
re_bool_statenum = []

for row in dropdown[:306]:
    string = row[1]
    re_bool_statenum.append(
        bool(re.search(pattern_statenum,string))
    )

assert(sum(re_bool_statenum) == 0)

# %%
# extract state name for RSAs

pattern = '([A-Za-z]+)(?:\s)(\d+)(?: - )(\D+)'

for row in dropdown:
    string = row[1]
    m = re.search(pattern, string)
    if m:
        row.append(list(m.groups()))
    else:
        row.append([])

# %%
# flatten last

# %%
dropdown_cols = ['cma_code', 'cma_dscr', 'area_type', 'msa_state', 'rsa_dscr']
dropdown_df = pd.DataFrame(dropdown, columns=dropdown_cols)

# %%
# extract number component of CMA code

dropdown_df.insert(0, 'CMA', dropdown_df['cma_code'].apply(lambda x: x[3:]))

# %%
dropdown_4merge = dropdown_df.drop(['cma_code', 'msa_state', 'rsa_dscr'], 1)

# %% [markdown]
# ### join cma-cnty with cma-dropdown

# %%
# import cma to county lookup table
# downloaded from https://www.cellularmaps.com/fcc_markets.shtml

cnty_df = pd.read_excel(path_to_cmacnty)

# %%
# pad CMA to string of length 3 for join with cma_lookup
cnty_df['CMA'] = cnty_df['CMA'].apply(lambda x: str(x).zfill(3))

# %%
# left merge cma_cnty info with dropdown descriptions using CMA

cnty_dropdown = cnty_df.merge(dropdown_4merge, on='CMA')

# %%
# 
cnty_dropdown.sort_values(by='CMA')

# how many states in each CMA
gb_CMA = cnty_dropdown.groupby('CMA')
gb_CMA.nunique()

# how many CMAs in particular state
gb_state = cnty_dropdown.groupby('State')
gb_state.nunique()
# Out:
#        County  State  FIPS  CMA  cma_dscr  area_type
# State
# AK         25      1    25    4         4          2
# AL         67      1    67   18        18          2
# AR         75      1    75   18        18          2
# AS          5      1     5    1         1          1
# AZ         15      1    15    8         8          2
# CA         58      1    58   31        31          2
# CO         63      1    63   14        14          2
# CT          8      1     8    6         6          2
# DC          1      1     1    1         1          1
# DE          3      1     3    2         2          2
# FL         67      1    67   29        29          2
# GA        159      1   159   22        22          2
# GM          1      1     1    1         1          1
# GU          1      1     1    1         1          1
# HI          5      1     5    4         4          2
# IA         99      1    99   24        24          2
# ID         44      1    44    7         7          2
# IL        102      1   102   22        22          2
# IN         92      1    92   23        23          2
# KS        105      1   105   19        19          2
# KY        120      1   120   18        18          2
# LA         64      1    64   17        17          2
# MA         14      1    14    7         7          2
# MD         24      1    24    8         8          2
# ME         16      1    16    8         8          2
# MI         83      1    83   21        21          2
# MN         87      1    87   17        17          2
# MO        115      1   115   25        25          2
# MP          4      1     4    1         1          1
# MS         82      1    82   15        15          2
# MT         57      1    57   12        12          2
# NC        100      1   100   25        25          2
# ND         53      1    53    8         8          2
# NE         93      1    93   13        13          2
# NH         10      1    10    5         5          2
# NJ         21      1    21   12        12          2
# NM         33      1    33    8         8          2
# NV         17      1    17    7         7          2
# NY         62      1    62   17        17          2
# OH         88      1    88   28        28          2
# OK         77      1    77   15        15          2
# OR         36      1    36   10        10          2
# PA         67      1    67   27        27          2
# PR         78      1    78   12        12          2
# RI          5      1     5    2         2          2
# SC         46      1    46   15        15          2
# SD         66      1    66   11        11          2
# TN         95      1    95   15        15          2
# TX        254      1   254   47        47          2
# UT         29      1    29    8         8          2
# VA        136      1   136   22        22          2
# VI          3      1     3    2         2          1
# VT         14      1    14    3         3          2
# WA         39      1    39   17        17          2
# WI         72      1    72   23        23          2
# WV         55      1    55   13        13          2
# WY         23      1    23    6         6          2

# %% [markdown]
# ## Merge dropdown & county info with scraped callsigns

# %% [markdown]
# ### Import and join amend searches from csv

# %%
amend_files = os.listdir('search-cache/csv/')[1:]
print(amend_files)
# Out:
# ['amend_CMA318_CMA722.csv', 'lt_10_CMA001_CMA734.csv', 'amend_CMA002_CMA317.csv']

# %%
search_cols = ['cma_no', 'callsign_leaseID', 'FRN_name', 'FRN_no', 'radio_service', 'status', 'date_expr' ]
combined = []

for f in amend_files:
    with open(('search-cache/csv/%s' % f), 'r', newline='') as table:
        reader = csv.reader(table)
        combined += list(reader)

pd.DataFrame(combined, columns=search_cols)
# Out:
#       cma_no callsign_leaseID  \
# 0     CMA318          KNKN268
# 1     CMA318          KNKQ365
# 2     CMA318          KNKR314
# 3     CMA318       L000022707
# 4     CMA318       L000022708
# 5     CMA318          WPQL769
# 6     CMA318          WPWV241
# 7     CMA318          WQGD712
# 8     CMA318          WQJQ674
# 9     CMA318          WQKQ560
# 10    CMA318          WQNG552
# 11    CMA318          WQVP469
# 12    CMA318          WQYX348
# 13    CMA319          KNKN232
# 14    CMA319          KNKQ379
# 15    CMA319          KNKR335
# 16    CMA319          KNNA208
# 17    CMA319          KNNA209
# 18    CMA319          KNNA210
# 19    CMA319          KNNA211
# 20    CMA319          KNNA212
# 21    CMA319          KNNA213
# 22    CMA319          KNNA214
# 23    CMA319          KNNA215
# 24    CMA319          KNNA216
# 25    CMA319       L000005004
# 26    CMA319       L000010755
# 27    CMA319       L000030986
# 28    CMA319       L000031026
# 29    CMA319          WPWV242
# ...      ...              ...
# 9297  CMA316          WQGD637
# 9298  CMA316          WQIQ306
# 9299  CMA316          WQIQ784
# 9300  CMA316          WQIZ597
# 9301  CMA316          WQLC364
# 9302  CMA316          WQLF434
# 9303  CMA316          WQWQ808
# 9304  CMA316          WQWV601
# 9305  CMA316          WRBT330
# 9306  CMA317          KNKN261
# 9307  CMA317          KNKQ316
# 9308  CMA317          KNKQ435
# 9309  CMA317          KNNA200
# 9310  CMA317          KNNA201
# 9311  CMA317          KNNA202
# 9312  CMA317          KNNA203
# 9313  CMA317          KNNA204
# 9314  CMA317          KNNA205
# 9315  CMA317          KNNA206
# 9316  CMA317          KNNA207
# 9317  CMA317       L000002684
# 9318  CMA317       L000031728
# 9319  CMA317       L000033668
# 9320  CMA317          WPWU972
# 9321  CMA317          WQGB262
# 9322  CMA317          WQIZ598
# 9323  CMA317          WQQZ490
# 9324  CMA317          WQSL580
# 9325  CMA317          WQVA555
# 9326  CMA317          WQWQ809
#
#                                                FRN_name      FRN_no  \
# 0                            AT&T Mobility Spectrum LLC  0014980726
# 1                            Verizon Wireless (VAW) LLC  0003800307
# 2                                    ALLTEL Corporation  0002942159
# 3                            AT&T Mobility Spectrum LLC  0014980726
# 4                            AT&T Mobility Spectrum LLC  0014980726
# 5                         Dobson Cellular Systems, Inc.
# 6                            AT&T Mobility Spectrum LLC  0014980726
# 7                            AT&T Mobility Spectrum LLC  0014980726
# 8                                Data-Max Wireless, LLC  0017166422
# 9                        Tisdale Telephone Company, LLC  0018115550
# 10                       Tisdale Telephone Company, LLC  0018115550
# 11                  Gila River Telecommunications, Inc.  0004052791
# 12                           AT&T Mobility Spectrum LLC  0014980726
# 13                           Verizon Wireless (VAW) LLC  0003800307
# 14                                   ALLTEL Corporation  0002942159
# 15                                   SMITH BAGLEY, INC.  0002154706
# 16            ANDERSON, HELEN / ALPHA TRUST PARTNERSHIP
# 17             ESTRADA, BARBARA / ETA TRUST PARTNERSHIP
# 18            MARSHALL, BRIAN / THETA TRUST PARTNERSHIP
# 19             MOSELEY, DONNA / DELTA TRUST PARTNERSHIP
# 20                 NOLAN, LORI / ZETA TRUST PARTNERSHIP
# 21             ROOKS, MABLE / EPSILON TRUST PARTNERSHIP
# 22              SCHULTZ, JULIE / BETA TRUST PARTNERSHIP
# 23                SIEV, KENNETH / CHI TRUST PARTNERSHIP
# 24           SPRUILL, MEREDITH / IOTA TRUST PARTNERSHIP
# 25            James H. Wanserski, Hold Separate Trustee  0018360701
# 26                                   Smith Bagley, Inc.  0002154706
# 27                              SBI License Corporation  0026071415
# 28                              SBI License Corporation  0026071415
# 29                           AT&T Mobility Spectrum LLC  0014980726
# ...                                                 ...         ...
# 9297                                 Cellco Partnership  0003290673
# 9298                           TelAlaska Cellular, Inc.  0003740768
# 9299                            Windy City Cellular LLC  0017413329
# 9300                         AT&T Mobility Spectrum LLC  0014980726
# 9301                       Copper Valley Wireless, Inc.  0001568302
# 9302                           TelAlaska Cellular, Inc.  0003740768
# 9303                            Northstar Wireless, LLC  0023917453
# 9304                   The Alaska Wireless Newtork, LLC  0021818133
# 9305                                      OptimEra Inc.  0021762067
# 9306                   The Alaska Wireless Network, LLC  0021818133
# 9307                         AT&T Mobility Spectrum LLC  0014980726
# 9308                 PACIFIC TELECOM CELLULAR OF ALASKA
# 9309                    ALT, PAUL/CHI TRUST PARTNERSHIP
# 9310               BACH, PHILLIP/ZETA TRUST PARTNERSHIP
# 9311              BERGER, VINCENT/ETA TRUST PARTNERSHIP
# 9312             BONDS, FAY / EPSILON TRUST PARTNERSHIP
# 9313           BRISCOE, BRIAN / DELTA TRUST PARTNERSHIP
# 9314             BROWN, GLORIA / BETA TRUST PARTNERSHIP
# 9315              BRUCE, TOBY / ALPHA TRUST PARTNERSHIP
# 9316             NELSON, GLEN / THETA TRUST PARTNERSHIP
# 9317                               Kwaan Wireless, Inc.  0017357146
# 9318   City of Ketchikan dba Ketchikan Public Utilities  0004325148
# 9319               Cordova Wireless Communications, LLC  0004333589
# 9320   City of Ketchikan dba Ketchikan Public Utilities  0004325148
# 9321  City of Ketchikan d.b.a. Ketchikan Public Util...  0004325148
# 9322                         AT&T Mobility Spectrum LLC  0014980726
# 9323                   The Alaska Wireless Network, LLC  0021818133
# 9324                                 Cellco Partnership  0003290673
# 9325                   The Alaska Wireless Network, LLC  0021818133
# 9326                            Northstar Wireless, LLC  0023917453
#
#      radio_service      status   date_expr
# 0               CL      Active  10/01/2020
# 1               CL      Active  10/01/2022
# 2               CL      Active  01/19/2029
# 3               WY     Expired  09/22/2016
# 4               WY    Canceled  09/22/2017
# 5               CL     Expired  11/23/2000
# 6               WZ      Active  06/13/2019
# 7               AW      Active  12/18/2021
# 8               WY      Active  06/13/2019
# 9               CL  Terminated  08/12/2019
# 10              CL      Active  01/31/2021
# 11              AT      Active  04/08/2027
# 12              WY      Active  06/13/2019
# 13              CL      Active  10/01/2020
# 14              CL      Active  10/01/2023
# 15              CL    Canceled  04/23/2008
# 16              CL    Canceled
# 17              CL    Canceled
# 18              CL    Canceled
# 19              CL    Canceled
# 20              CL    Canceled
# 21              CL    Canceled
# 22              CL    Canceled
# 23              CL    Canceled
# 24              CL    Canceled
# 25              CL    Canceled  12/30/2009
# 26              WY     Expired  01/20/2014
# 27              WZ    Canceled  03/12/2019
# 28              WZ      Active  06/13/2019
# 29              WZ      Active  06/13/2019
# ...            ...         ...         ...
# 9297            AW      Active  12/18/2021
# 9298            CL      Active  04/11/2028
# 9299            CL      Active  04/16/2028
# 9300            WY      Active  06/13/2019
# 9301            CL     Expired  10/04/2011
# 9302            CL      Active  10/01/2019
# 9303            AT      Active  10/27/2027
# 9304            CL     Expired  02/02/2016
# 9305            CL      Active  06/12/2028
# 9306            CL      Active  10/01/2020
# 9307            CL      Active  10/01/2021
# 9308            CL  Terminated
# 9309            CL    Canceled
# 9310            CL    Canceled
# 9311            CL    Canceled
# 9312            CL    Canceled
# 9313            CL    Canceled
# 9314            CL    Canceled
# 9315            CL    Canceled
# 9316            CL    Canceled
# 9317            WZ  Terminated  01/01/2015
# 9318            AW      Active  11/29/2021
# 9319            WY      Active  06/13/2019
# 9320            WZ      Active  06/13/2019
# 9321            AW      Active  11/29/2021
# 9322            WY      Active  06/13/2019
# 9323            CL      Active  03/29/2023
# 9324            AW      Active  11/29/2021
# 9325            CL     Expired  02/06/2015
# 9326            AT      Active  10/27/2027
#
# [9327 rows x 7 columns]

# %%
print("length of combined file", len(pd.DataFrame(combined)))
combined_df = (pd.DataFrame(combined, columns=search_cols)
               .drop_duplicates()
               .sort_values(by='cma_no')
              )
print("length of combined unique df", len(combined_df))
# Out:
# length of combined file 9327
# length of combined unique df 6947

# %%
# save combined df to data-cache

combined_df.to_csv(path_or_buf='data-cache/cma_search_results_ALL.csv')

# %%
# filter for Cellular Licenses only
is_CL = (combined_df['radio_service'] == 'CL')
CL_df = combined_df[is_CL]

# save cellular-cma list to data-cache

CL_df.to_csv(path_or_buf='data-cache/cma_search_results_CL-only.csv')


# extract number component of CMA code
CL_df.insert(0,
             'CMA',
             CL_df['cma_no'].apply(lambda x: x[3:]))

# create look up table
CLsearch_4merge = CL_df.filter(['CMA', 'callsign_leaseID'])

# %%
# merge table of cma+counties with callsigns

callsigns_loc = CLsearch_4merge.merge(cnty_dropdown, on='CMA')

# %%
callsigns_loc.head()
# Out:
#    CMA callsign_leaseID   County State   FIPS                        cma_dscr  \
# 0  001          KNKA206   Bergen    NJ  34003  New York, NY-NJ/Nassau-Suffolk
# 1  001          KNKA206    Essex    NJ  34013  New York, NY-NJ/Nassau-Suffolk
# 2  001          KNKA206   Hudson    NJ  34017  New York, NY-NJ/Nassau-Suffolk
# 3  001          KNKA206   Morris    NJ  34027  New York, NY-NJ/Nassau-Suffolk
# 4  001          KNKA206  Passaic    NJ  34031  New York, NY-NJ/Nassau-Suffolk
#
#   area_type
# 0       MSA
# 1       MSA
# 2       MSA
# 3       MSA
# 4       MSA

# %%
cma_2_callsign = (callsigns_cma.groupby(['CMA', 'callsign_leaseID']).count()
                  .reset_index())[['CMA','callsign_leaseID']]

cma_2_callsign
# Out:
#       CMA callsign_leaseID
# 0     001          KNKA206
# 1     001          KNKA310
# 2     002          KNKA209
# 3     002          KNKA351
# 4     002          KNKR294
# 5     002          KNKR313
# 6     002       L000015067
# 7     002          WPOI449
# 8     003          KNKA200
# 9     003          KNKA254
# 10    004          KNKA204
# 11    004          KNKA382
# 12    005          KNKA231
# 13    005          KNKA244
# 14    006          KNKA201
# 15    006          KNKA226
# 16    006          WPOI233
# 17    007          KNKA228
# 18    007          KNKA274
# 19    007          KNKR203
# 20    008          KNKA230
# 21    008          KNKA243
# 22    009          KNKA229
# 23    009          KNKA400
# 24    010          KNKA221
# 25    010          KNKA367
# 26    011          KNKA218
# 27    011          KNKA234
# 28    011          KNKR204
# 29    011          WPOI275
# ...   ...              ...
# 2573  722       L000006599
# 2574  723          KNKN505
# 2575  723          KNKN682
# 2576  724          KNKN532
# 2577  724          KNKN843
# 2578  725          KNKN371
# 2579  725          KNKN517
# 2580  726          KNKN397
# 2581  726          KNKQ343
# 2582  727          KNKN414
# 2583  727          KNKQ240
# 2584  727          KNKQ241
# 2585  727          WPVV300
# 2586  728          KNKN486
# 2587  728          KNKQ239
# 2588  728          KNKQ362
# 2589  729          KNKN521
# 2590  729          KNKN957
# 2591  730          KNKN524
# 2592  730          KNKN845
# 2593  731          KNKN523
# 2594  731          KNKN846
# 2595  732          KNKN828
# 2596  732          KNKQ317
# 2597  733          KNKN718
# 2598  733          KNKR259
# 2599  733          WQHM554
# 2600  734          KNKN616
# 2601  734          KNKQ367
# 2602  734          WQPT486
#
# [2603 rows x 2 columns]

# %%
# cache to csv

callsigns_loc.to_csv('data-cache/cma_callsign_county.csv')

cma_2_callsign.to_csv('data-cache/cma_callsign_lookup.csv')
